# %% [markdown]
# # Deliverable 1: Retrieve Weather Data

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of 2,000 random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Import the citipy module 
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 766

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Build the basic URL for the OpenWeatherMap with your weather_api_key added to the URL
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

#print(url)

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_current_description = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard.
        #city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_current_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")


# Loop through all the cities in our list.
for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + cities[i]
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | puerto ayora
# Processing Record 2 of Set 1 | albany
# Processing Record 3 of Set 1 | khatanga
# Processing Record 4 of Set 1 | samalaeulu
# City not found. Skipping...
# Processing Record 5 of Set 1 | tondi
# Processing Record 6 of Set 1 | port hedland
# Processing Record 7 of Set 1 | udachnyy
# Processing Record 8 of Set 1 | bethel
# Processing Record 9 of Set 1 | seoul
# Processing Record 10 of Set 1 | jamestown
# Processing Record 11 of Set 1 | tezu
# Processing Record 12 of Set 1 | kapaa
# Processing Record 13 of Set 1 | rikitea
# Processing Record 14 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 15 of Set 1 | guerrero negro
# Processing Record 16 of Set 1 | arraial do cabo
# Processing Record 17 of Set 1 | saskylakh
# Processing Record 18 of Set 1 | lodwar
# Processing Record 19 of Set 1 | guayaramerin
# Processing Record 20 of Set 1 | esperance
# Processing Record 21 of Set 1 | punta arenas
# Processing Record 22 of Set 1 | terrace
# Processing Record 23 of Set 1 | avera
# Processing Record 24 of Set 1 | cape town
# Processing Record 25 of Set 1 | sorland
# Processing Record 26 of Set 1 | nanga eboko
# Processing Record 27 of Set 1 | faanui
# Processing Record 28 of Set 1 | ushuaia
# Processing Record 29 of Set 1 | tuktoyaktuk
# Processing Record 30 of Set 1 | petropavlovsk-kamchatskiy
# Processing Record 31 of Set 1 | vaini
# Processing Record 32 of Set 1 | belmonte
# Processing Record 33 of Set 1 | kahului
# Processing Record 34 of Set 1 | hilo
# Processing Record 35 of Set 1 | dikson
# Processing Record 36 of Set 1 | rio grande
# Processing Record 37 of Set 1 | kavieng
# Processing Record 38 of Set 1 | saint anthony
# Processing Record 39 of Set 1 | laguna
# Processing Record 40 of Set 1 | sitka
# Processing Record 41 of Set 1 | klaksvik
# Processing Record 42 of Set 1 | chiredzi
# Processing Record 43 of Set 1 | todos santos
# Processing Record 44 of Set 1 | itaunja
# Processing Record 45 of Set 1 | busselton
# Processing Record 46 of Set 1 | lebu
# Processing Record 47 of Set 1 | korla
# Processing Record 48 of Set 1 | bengkulu
# Processing Record 49 of Set 1 | sioux lookout
# Processing Record 50 of Set 1 | yellowknife
# Processing Record 1 of Set 2 | atuona
# Processing Record 2 of Set 2 | port alfred
# Processing Record 3 of Set 2 | salalah
# Processing Record 4 of Set 2 | upernavik
# Processing Record 5 of Set 2 | saint-augustin
# Processing Record 6 of Set 2 | port macquarie
# Processing Record 7 of Set 2 | lata
# Processing Record 8 of Set 2 | walvis bay
# Processing Record 9 of Set 2 | ballina
# Processing Record 10 of Set 2 | hithadhoo
# Processing Record 11 of Set 2 | klyuchi
# Processing Record 12 of Set 2 | thompson
# Processing Record 13 of Set 2 | mar del plata
# Processing Record 14 of Set 2 | qaanaaq
# Processing Record 15 of Set 2 | bredasdorp
# Processing Record 16 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 17 of Set 2 | ostrovnoy
# Processing Record 18 of Set 2 | puerto del rosario
# Processing Record 19 of Set 2 | ulundi
# Processing Record 20 of Set 2 | yerbogachen
# Processing Record 21 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 22 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 23 of Set 2 | iqaluit
# Processing Record 24 of Set 2 | the valley
# Processing Record 25 of Set 2 | santa maria
# Processing Record 26 of Set 2 | zaranj
# Processing Record 27 of Set 2 | bluff
# Processing Record 28 of Set 2 | ardakan
# Processing Record 29 of Set 2 | faya
# Processing Record 30 of Set 2 | zhezkazgan
# Processing Record 31 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 32 of Set 2 | haines junction
# Processing Record 33 of Set 2 | maceio
# Processing Record 34 of Set 2 | souillac
# Processing Record 35 of Set 2 | fomboni
# Processing Record 36 of Set 2 | chokurdakh
# Processing Record 37 of Set 2 | cascais
# Processing Record 38 of Set 2 | grand forks
# Processing Record 39 of Set 2 | azimur
# City not found. Skipping...
# Processing Record 40 of Set 2 | westport
# Processing Record 41 of Set 2 | codo
# Processing Record 42 of Set 2 | riberalta
# Processing Record 43 of Set 2 | fortuna
# Processing Record 44 of Set 2 | vila franca do campo
# Processing Record 45 of Set 2 | victor harbor
# Processing Record 46 of Set 2 | egtved
# Processing Record 47 of Set 2 | kodinsk
# Processing Record 48 of Set 2 | illapel
# Processing Record 49 of Set 2 | deputatskiy
# Processing Record 50 of Set 2 | willowmore
# Processing Record 1 of Set 3 | marabba
# Processing Record 2 of Set 3 | bolobo
# Processing Record 3 of Set 3 | cherskiy
# Processing Record 4 of Set 3 | ukiah
# Processing Record 5 of Set 3 | new norfolk
# Processing Record 6 of Set 3 | maneadero
# Processing Record 7 of Set 3 | tiksi
# Processing Record 8 of Set 3 | hobart
# Processing Record 9 of Set 3 | acapulco
# Processing Record 10 of Set 3 | havoysund
# Processing Record 11 of Set 3 | meulaboh
# Processing Record 12 of Set 3 | saint george
# Processing Record 13 of Set 3 | barrow
# Processing Record 14 of Set 3 | urumqi
# Processing Record 15 of Set 3 | amod
# Processing Record 16 of Set 3 | college
# Processing Record 17 of Set 3 | abha
# Processing Record 18 of Set 3 | mandla
# Processing Record 19 of Set 3 | tasiilaq
# Processing Record 20 of Set 3 | karlivka
# Processing Record 21 of Set 3 | talnakh
# Processing Record 22 of Set 3 | rionegro
# Processing Record 23 of Set 3 | manggar
# Processing Record 24 of Set 3 | saint-philippe
# Processing Record 25 of Set 3 | romitan
# Processing Record 26 of Set 3 | mangan
# Processing Record 27 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 28 of Set 3 | ponta delgada
# Processing Record 29 of Set 3 | killybegs
# Processing Record 30 of Set 3 | mataura
# Processing Record 31 of Set 3 | lompoc
# Processing Record 32 of Set 3 | oussouye
# Processing Record 33 of Set 3 | butaritari
# Processing Record 34 of Set 3 | imeni poliny osipenko
# Processing Record 35 of Set 3 | tucurui
# Processing Record 36 of Set 3 | fairbanks
# Processing Record 37 of Set 3 | dingle
# Processing Record 38 of Set 3 | dillon
# Processing Record 39 of Set 3 | longyearbyen
# Processing Record 40 of Set 3 | lasa
# Processing Record 41 of Set 3 | warrnambool
# Processing Record 42 of Set 3 | srednekolymsk
# Processing Record 43 of Set 3 | saldanha
# Processing Record 44 of Set 3 | mayumba
# Processing Record 45 of Set 3 | hermanus
# Processing Record 46 of Set 3 | port lincoln
# Processing Record 47 of Set 3 | tazovskiy
# Processing Record 48 of Set 3 | mahebourg
# Processing Record 49 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 50 of Set 3 | severo-kurilsk
# Processing Record 1 of Set 4 | punta alta
# Processing Record 2 of Set 4 | hofn
# Processing Record 3 of Set 4 | vila velha
# Processing Record 4 of Set 4 | marsh harbour
# Processing Record 5 of Set 4 | domoni
# Processing Record 6 of Set 4 | quatre cocos
# Processing Record 7 of Set 4 | arica
# Processing Record 8 of Set 4 | novo aripuana
# Processing Record 9 of Set 4 | baie-comeau
# Processing Record 10 of Set 4 | qianan
# Processing Record 11 of Set 4 | provideniya
# Processing Record 12 of Set 4 | east london
# Processing Record 13 of Set 4 | waipawa
# Processing Record 14 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 15 of Set 4 | nyurba
# Processing Record 16 of Set 4 | mgachi
# Processing Record 17 of Set 4 | opobo
# City not found. Skipping...
# Processing Record 18 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 19 of Set 4 | camopi
# Processing Record 20 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 21 of Set 4 | rudnogorsk
# Processing Record 22 of Set 4 | shima
# Processing Record 23 of Set 4 | chuy
# Processing Record 24 of Set 4 | skagastrond
# City not found. Skipping...
# Processing Record 25 of Set 4 | kyren
# Processing Record 26 of Set 4 | warqla
# City not found. Skipping...
# Processing Record 27 of Set 4 | uspenka
# Processing Record 28 of Set 4 | hasaki
# Processing Record 29 of Set 4 | aksha
# Processing Record 30 of Set 4 | san quintin
# Processing Record 31 of Set 4 | rawson
# Processing Record 32 of Set 4 | palimbang
# Processing Record 33 of Set 4 | georgetown
# Processing Record 34 of Set 4 | morehead
# Processing Record 35 of Set 4 | kudahuvadhoo
# Processing Record 36 of Set 4 | kuche
# City not found. Skipping...
# Processing Record 37 of Set 4 | muros
# Processing Record 38 of Set 4 | pisco
# Processing Record 39 of Set 4 | coahuayana
# Processing Record 40 of Set 4 | grand gaube
# Processing Record 41 of Set 4 | jinka
# Processing Record 42 of Set 4 | tuatapere
# Processing Record 43 of Set 4 | eenhana
# Processing Record 44 of Set 4 | carnarvon
# Processing Record 45 of Set 4 | axim
# Processing Record 46 of Set 4 | bang saphan
# Processing Record 47 of Set 4 | sovetskiy
# Processing Record 48 of Set 4 | pavlodar
# Processing Record 49 of Set 4 | hami
# Processing Record 50 of Set 4 | mount isa
# Processing Record 1 of Set 5 | tromso
# Processing Record 2 of Set 5 | avarua
# Processing Record 3 of Set 5 | kaitangata
# Processing Record 4 of Set 5 | ksenyevka
# City not found. Skipping...
# Processing Record 5 of Set 5 | ouadda
# Processing Record 6 of Set 5 | udomlya
# Processing Record 7 of Set 5 | makokou
# Processing Record 8 of Set 5 | pochutla
# Processing Record 9 of Set 5 | sao joao da barra
# Processing Record 10 of Set 5 | kerki
# City not found. Skipping...
# Processing Record 11 of Set 5 | moerai
# Processing Record 12 of Set 5 | berlevag
# Processing Record 13 of Set 5 | solsvik
# City not found. Skipping...
# Processing Record 14 of Set 5 | mehamn
# Processing Record 15 of Set 5 | marigot
# Processing Record 16 of Set 5 | beringovskiy
# Processing Record 17 of Set 5 | general pico
# Processing Record 18 of Set 5 | kaspiysk
# Processing Record 19 of Set 5 | castro
# Processing Record 20 of Set 5 | micheweni
# Processing Record 21 of Set 5 | cap malheureux
# Processing Record 22 of Set 5 | saint-joseph
# Processing Record 23 of Set 5 | florianopolis
# Processing Record 24 of Set 5 | buraydah
# Processing Record 25 of Set 5 | aras
# Processing Record 26 of Set 5 | payakumbuh
# Processing Record 27 of Set 5 | ponta do sol
# Processing Record 28 of Set 5 | verkhoyansk
# Processing Record 29 of Set 5 | stornoway
# Processing Record 30 of Set 5 | pingliang
# Processing Record 31 of Set 5 | nanortalik
# Processing Record 32 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 33 of Set 5 | caravelas
# Processing Record 34 of Set 5 | sao filipe
# Processing Record 35 of Set 5 | kloulklubed
# Processing Record 36 of Set 5 | bambous virieux
# Processing Record 37 of Set 5 | riverton
# Processing Record 38 of Set 5 | cockburn harbour
# City not found. Skipping...
# Processing Record 39 of Set 5 | sawakin
# Processing Record 40 of Set 5 | isangel
# Processing Record 41 of Set 5 | sirpur
# Processing Record 42 of Set 5 | narsaq
# Processing Record 43 of Set 5 | xinzhi
# Processing Record 44 of Set 5 | chelno-vershiny
# Processing Record 45 of Set 5 | codrington
# Processing Record 46 of Set 5 | basqal
# Processing Record 47 of Set 5 | nikolskoye
# Processing Record 48 of Set 5 | ancud
# Processing Record 49 of Set 5 | camacha
# Processing Record 50 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 1 of Set 6 | ugoofaaru
# Processing Record 2 of Set 6 | havre-saint-pierre
# Processing Record 3 of Set 6 | little current
# Processing Record 4 of Set 6 | nouadhibou
# Processing Record 5 of Set 6 | tsiroanomandidy
# Processing Record 6 of Set 6 | nayoro
# Processing Record 7 of Set 6 | nogales
# Processing Record 8 of Set 6 | airai
# Processing Record 9 of Set 6 | ginda
# Processing Record 10 of Set 6 | sao jose da coroa grande
# Processing Record 11 of Set 6 | benghazi
# Processing Record 12 of Set 6 | klimovo
# Processing Record 13 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 14 of Set 6 | norman wells
# Processing Record 15 of Set 6 | luderitz
# Processing Record 16 of Set 6 | bundaberg
# Processing Record 17 of Set 6 | mildura
# Processing Record 18 of Set 6 | vao
# Processing Record 19 of Set 6 | vanavara
# Processing Record 20 of Set 6 | olmos
# Processing Record 21 of Set 6 | santa rosa
# Processing Record 22 of Set 6 | kuytun
# Processing Record 23 of Set 6 | saint-francois
# Processing Record 24 of Set 6 | atambua
# Processing Record 25 of Set 6 | constitucion
# Processing Record 26 of Set 6 | mineiros
# Processing Record 27 of Set 6 | belaya gora
# Processing Record 28 of Set 6 | thinadhoo
# Processing Record 29 of Set 6 | cidreira
# Processing Record 30 of Set 6 | sandwick
# Processing Record 31 of Set 6 | limbang
# Processing Record 32 of Set 6 | kuching
# Processing Record 33 of Set 6 | kindia
# Processing Record 34 of Set 6 | asau
# Processing Record 35 of Set 6 | platanos
# Processing Record 36 of Set 6 | broken hill
# Processing Record 37 of Set 6 | natal
# Processing Record 38 of Set 6 | leningradskiy
# Processing Record 39 of Set 6 | agadez
# Processing Record 40 of Set 6 | faridabad
# Processing Record 41 of Set 6 | praia da vitoria
# Processing Record 42 of Set 6 | buchanan
# Processing Record 43 of Set 6 | varhaug
# Processing Record 44 of Set 6 | san mateo del mar
# Processing Record 45 of Set 6 | aktau
# Processing Record 46 of Set 6 | grindavik
# Processing Record 47 of Set 6 | lorengau
# Processing Record 48 of Set 6 | harthill
# Processing Record 49 of Set 6 | elban
# Processing Record 50 of Set 6 | springdale
# Processing Record 1 of Set 7 | sataua
# City not found. Skipping...
# Processing Record 2 of Set 7 | carutapera
# Processing Record 3 of Set 7 | ilulissat
# Processing Record 4 of Set 7 | general teran
# Processing Record 5 of Set 7 | okha
# Processing Record 6 of Set 7 | lavrentiya
# Processing Record 7 of Set 7 | yeletskiy
# City not found. Skipping...
# Processing Record 8 of Set 7 | bandarbeyla
# Processing Record 9 of Set 7 | palmares do sul
# Processing Record 10 of Set 7 | praia
# Processing Record 11 of Set 7 | pangnirtung
# Processing Record 12 of Set 7 | yulara
# Processing Record 13 of Set 7 | vostok
# Processing Record 14 of Set 7 | picos
# Processing Record 15 of Set 7 | sulya
# Processing Record 16 of Set 7 | port elizabeth
# Processing Record 17 of Set 7 | san andres
# Processing Record 18 of Set 7 | saint-georges
# Processing Record 19 of Set 7 | mrirt
# City not found. Skipping...
# Processing Record 20 of Set 7 | halifax
# Processing Record 21 of Set 7 | flin flon
# Processing Record 22 of Set 7 | viedma
# Processing Record 23 of Set 7 | fort nelson
# Processing Record 24 of Set 7 | torbay
# Processing Record 25 of Set 7 | lac du bonnet
# Processing Record 26 of Set 7 | bagdarin
# Processing Record 27 of Set 7 | cabo san lucas
# Processing Record 28 of Set 7 | qandahar
# City not found. Skipping...
# Processing Record 29 of Set 7 | samana
# Processing Record 30 of Set 7 | rio gallegos
# Processing Record 31 of Set 7 | owando
# Processing Record 32 of Set 7 | slupsk
# Processing Record 33 of Set 7 | inhambane
# Processing Record 34 of Set 7 | arkhangelskoye
# Processing Record 35 of Set 7 | alofi
# Processing Record 36 of Set 7 | monrovia
# Processing Record 37 of Set 7 | santa adelia
# Processing Record 38 of Set 7 | christchurch
# Processing Record 39 of Set 7 | maple creek
# Processing Record 40 of Set 7 | mugur-aksy
# Processing Record 41 of Set 7 | manzil jamil
# City not found. Skipping...
# Processing Record 42 of Set 7 | henties bay
# Processing Record 43 of Set 7 | ransang
# Processing Record 44 of Set 7 | kavaratti
# Processing Record 45 of Set 7 | glyadyanskoye
# Processing Record 46 of Set 7 | nishihara
# Processing Record 47 of Set 7 | ulladulla
# Processing Record 48 of Set 7 | jalu
# Processing Record 49 of Set 7 | dwarka
# Processing Record 50 of Set 7 | ribeira grande
# Processing Record 1 of Set 8 | vidim
# Processing Record 2 of Set 8 | shkotovo-26
# City not found. Skipping...
# Processing Record 3 of Set 8 | shchelyayur
# City not found. Skipping...
# Processing Record 4 of Set 8 | tual
# Processing Record 5 of Set 8 | shimoda
# Processing Record 6 of Set 8 | hambantota
# Processing Record 7 of Set 8 | rosas
# Processing Record 8 of Set 8 | apiai
# Processing Record 9 of Set 8 | barao de melgaco
# Processing Record 10 of Set 8 | bardiyah
# Processing Record 11 of Set 8 | navrongo
# Processing Record 12 of Set 8 | katsuura
# Processing Record 13 of Set 8 | giaginskaya
# Processing Record 14 of Set 8 | beloha
# Processing Record 15 of Set 8 | silvania
# Processing Record 16 of Set 8 | ladan
# Processing Record 17 of Set 8 | aklavik
# Processing Record 18 of Set 8 | high level
# Processing Record 19 of Set 8 | antofagasta
# Processing Record 20 of Set 8 | baykit
# Processing Record 21 of Set 8 | morro bay
# Processing Record 22 of Set 8 | maldonado
# Processing Record 23 of Set 8 | chagda
# City not found. Skipping...
# Processing Record 24 of Set 8 | te anau
# Processing Record 25 of Set 8 | oktyabrskoye
# Processing Record 26 of Set 8 | khorixas
# Processing Record 27 of Set 8 | sakakah
# Processing Record 28 of Set 8 | sibiti
# Processing Record 29 of Set 8 | auki
# Processing Record 30 of Set 8 | husavik
# Processing Record 31 of Set 8 | nome
# Processing Record 32 of Set 8 | villa carlos paz
# Processing Record 33 of Set 8 | kashan
# Processing Record 34 of Set 8 | magole
# Processing Record 35 of Set 8 | tynda
# Processing Record 36 of Set 8 | hachinohe
# Processing Record 37 of Set 8 | sterling
# Processing Record 38 of Set 8 | santa fe
# Processing Record 39 of Set 8 | dakar
# Processing Record 40 of Set 8 | dolgoye
# Processing Record 41 of Set 8 | san felipe
# Processing Record 42 of Set 8 | hamilton
# Processing Record 43 of Set 8 | matagami
# Processing Record 44 of Set 8 | chara
# Processing Record 45 of Set 8 | mitu
# Processing Record 46 of Set 8 | la uribe
# City not found. Skipping...
# Processing Record 47 of Set 8 | kirakira
# Processing Record 48 of Set 8 | harper
# Processing Record 49 of Set 8 | visby
# Processing Record 50 of Set 8 | kjollefjord
# Processing Record 1 of Set 9 | yaan
# Processing Record 2 of Set 9 | marsa matruh
# Processing Record 3 of Set 9 | dhidhdhoo
# Processing Record 4 of Set 9 | diffa
# Processing Record 5 of Set 9 | tabory
# Processing Record 6 of Set 9 | kijang
# Processing Record 7 of Set 9 | karratha
# Processing Record 8 of Set 9 | tungkang
# City not found. Skipping...
# Processing Record 9 of Set 9 | chapais
# Processing Record 10 of Set 9 | pokhara
# Processing Record 11 of Set 9 | labytnangi
# Processing Record 12 of Set 9 | severo-yeniseyskiy
# Processing Record 13 of Set 9 | rundu
# Processing Record 14 of Set 9 | manzanillo
# Processing Record 15 of Set 9 | togur
# Processing Record 16 of Set 9 | san jose
# Processing Record 17 of Set 9 | aparecida do taboado
# Processing Record 18 of Set 9 | clyde river
# Processing Record 19 of Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 20 of Set 9 | tilichiki
# Processing Record 21 of Set 9 | port blair
# Processing Record 22 of Set 9 | gerash
# Processing Record 23 of Set 9 | linhai
# Processing Record 24 of Set 9 | trincomalee
# Processing Record 25 of Set 9 | galiwinku
# City not found. Skipping...
# Processing Record 26 of Set 9 | tambul
# City not found. Skipping...
# Processing Record 27 of Set 9 | mahon
# Processing Record 28 of Set 9 | vizinga
# Processing Record 29 of Set 9 | tupik
# Processing Record 30 of Set 9 | ngunguru
# Processing Record 31 of Set 9 | tiznit
# Processing Record 32 of Set 9 | vardo
# Processing Record 33 of Set 9 | tabou
# Processing Record 34 of Set 9 | olafsvik
# Processing Record 35 of Set 9 | minudasht
# Processing Record 36 of Set 9 | buin
# Processing Record 37 of Set 9 | coquimbo
# Processing Record 38 of Set 9 | marzuq
# Processing Record 39 of Set 9 | shieli
# Processing Record 40 of Set 9 | whitehorse
# Processing Record 41 of Set 9 | kampong thum
# Processing Record 42 of Set 9 | wilmington
# Processing Record 43 of Set 9 | genhe
# Processing Record 44 of Set 9 | puerto escondido
# Processing Record 45 of Set 9 | portland
# Processing Record 46 of Set 9 | jinji
# Processing Record 47 of Set 9 | sola
# Processing Record 48 of Set 9 | lewistown
# Processing Record 49 of Set 9 | svetlyy
# Processing Record 50 of Set 9 | sur
# Processing Record 1 of Set 10 | beyneu
# Processing Record 2 of Set 10 | mackay
# Processing Record 3 of Set 10 | mikhaylovskoye
# Processing Record 4 of Set 10 | elizabeth city
# Processing Record 5 of Set 10 | bargal
# City not found. Skipping...
# Processing Record 6 of Set 10 | waddan
# Processing Record 7 of Set 10 | havelock
# Processing Record 8 of Set 10 | svetlogorsk
# Processing Record 9 of Set 10 | tres passos
# Processing Record 10 of Set 10 | araguari
# Processing Record 11 of Set 10 | caucaia
# Processing Record 12 of Set 10 | bandar
# Processing Record 13 of Set 10 | alamor
# Processing Record 14 of Set 10 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 15 of Set 10 | shurugwi
# Processing Record 16 of Set 10 | san patricio
# Processing Record 17 of Set 10 | dongsheng
# Processing Record 18 of Set 10 | san cristobal
# Processing Record 19 of Set 10 | port hardy
# Processing Record 20 of Set 10 | sulangan
# Processing Record 21 of Set 10 | namibe
# Processing Record 22 of Set 10 | nata
# Processing Record 23 of Set 10 | buenavista
# Processing Record 24 of Set 10 | murgab
# Processing Record 25 of Set 10 | lagoa
# Processing Record 26 of Set 10 | kodiak
# Processing Record 27 of Set 10 | tura
# Processing Record 28 of Set 10 | visimo-utkinsk
# City not found. Skipping...
# Processing Record 29 of Set 10 | ketchikan
# Processing Record 30 of Set 10 | bolungarvik
# City not found. Skipping...
# Processing Record 31 of Set 10 | wuwei
# Processing Record 32 of Set 10 | linjiang
# Processing Record 33 of Set 10 | muroto
# Processing Record 34 of Set 10 | bodden town
# Processing Record 35 of Set 10 | general salgado
# Processing Record 36 of Set 10 | savonlinna
# Processing Record 37 of Set 10 | rocha
# Processing Record 38 of Set 10 | nhulunbuy
# Processing Record 39 of Set 10 | bulgan
# Processing Record 40 of Set 10 | vysokogornyy
# Processing Record 41 of Set 10 | geraldton
# Processing Record 42 of Set 10 | amderma
# City not found. Skipping...
# Processing Record 43 of Set 10 | lysyye gory
# Processing Record 44 of Set 10 | teguise
# Processing Record 45 of Set 10 | malanje
# Processing Record 46 of Set 10 | delaware
# Processing Record 47 of Set 10 | pietarsaari
# Processing Record 48 of Set 10 | kismayo
# Processing Record 49 of Set 10 | alice springs
# Processing Record 50 of Set 10 | careiro da varzea
# Processing Record 1 of Set 11 | phetchabun
# Processing Record 2 of Set 11 | mount gambier
# Processing Record 3 of Set 11 | ulaanbaatar
# Processing Record 4 of Set 11 | khonuu
# City not found. Skipping...
# Processing Record 5 of Set 11 | bousso
# Processing Record 6 of Set 11 | yokadouma
# Processing Record 7 of Set 11 | takoradi
# Processing Record 8 of Set 11 | andros town
# Processing Record 9 of Set 11 | lazaro cardenas
# Processing Record 10 of Set 11 | divnomorskoye
# Processing Record 11 of Set 11 | qeshm
# Processing Record 12 of Set 11 | sukhobezvodnoye
# Processing Record 13 of Set 11 | sasciori
# Processing Record 14 of Set 11 | comodoro rivadavia
# Processing Record 15 of Set 11 | halalo
# City not found. Skipping...
# Processing Record 16 of Set 11 | aksay
# Processing Record 17 of Set 11 | shache
# Processing Record 18 of Set 11 | xinyu
# Processing Record 19 of Set 11 | ahipara
# Processing Record 20 of Set 11 | fairview
# Processing Record 21 of Set 11 | touros
# Processing Record 22 of Set 11 | tres arroyos
# Processing Record 23 of Set 11 | bhimunipatnam
# Processing Record 24 of Set 11 | kaeo
# Processing Record 25 of Set 11 | winnemucca
# Processing Record 26 of Set 11 | rio pomba
# Processing Record 27 of Set 11 | srivardhan
# Processing Record 28 of Set 11 | richard toll
# City not found. Skipping...
# Processing Record 29 of Set 11 | jizan
# Processing Record 30 of Set 11 | sinnamary
# Processing Record 31 of Set 11 | pudozh
# Processing Record 32 of Set 11 | hualmay
# Processing Record 33 of Set 11 | silver city
# Processing Record 34 of Set 11 | cayenne
# Processing Record 35 of Set 11 | rognan
# Processing Record 36 of Set 11 | hopelchen
# Processing Record 37 of Set 11 | pervomayskoye
# Processing Record 38 of Set 11 | ijaki
# City not found. Skipping...
# Processing Record 39 of Set 11 | vila
# Processing Record 40 of Set 11 | labuhan
# Processing Record 41 of Set 11 | sabang
# Processing Record 42 of Set 11 | koboldo
# City not found. Skipping...
# Processing Record 43 of Set 11 | pangai
# Processing Record 44 of Set 11 | pevek
# Processing Record 45 of Set 11 | otradnoye
# Processing Record 46 of Set 11 | tatawin
# Processing Record 47 of Set 11 | suntar
# Processing Record 48 of Set 11 | mezen
# Processing Record 49 of Set 11 | canavieiras
# Processing Record 50 of Set 11 | carroll
# Processing Record 1 of Set 12 | najran
# Processing Record 2 of Set 12 | key west
# Processing Record 3 of Set 12 | minna
# Processing Record 4 of Set 12 | ozgon
# City not found. Skipping...
# Processing Record 5 of Set 12 | jiexiu
# Processing Record 6 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 7 of Set 12 | gostyn
# Processing Record 8 of Set 12 | tumannyy
# City not found. Skipping...
# Processing Record 9 of Set 12 | aksarka
# Processing Record 10 of Set 12 | conakry
# Processing Record 11 of Set 12 | mercedes
# Processing Record 12 of Set 12 | taber
# Processing Record 13 of Set 12 | basco
# Processing Record 14 of Set 12 | victoria
# Processing Record 15 of Set 12 | smidovich
# Processing Record 16 of Set 12 | varazdin
# Processing Record 17 of Set 12 | murnau
# Processing Record 18 of Set 12 | kopargaon
# Processing Record 19 of Set 12 | roald
# Processing Record 20 of Set 12 | kandi
# Processing Record 21 of Set 12 | schruns
# Processing Record 22 of Set 12 | balsas
# Processing Record 23 of Set 12 | wajima
# Processing Record 24 of Set 12 | rockport
# Processing Record 25 of Set 12 | araceli
# Processing Record 26 of Set 12 | samusu
# City not found. Skipping...
# Processing Record 27 of Set 12 | tessalit
# Processing Record 28 of Set 12 | el reno
# Processing Record 29 of Set 12 | bud
# Processing Record 30 of Set 12 | marshall
# Processing Record 31 of Set 12 | trofors
# Processing Record 32 of Set 12 | hammerfest
# Processing Record 33 of Set 12 | atchison
# Processing Record 34 of Set 12 | gewane
# Processing Record 35 of Set 12 | kulhudhuffushi
# Processing Record 36 of Set 12 | richards bay
# Processing Record 37 of Set 12 | ende
# Processing Record 38 of Set 12 | adrar
# Processing Record 39 of Set 12 | ixtapa
# Processing Record 40 of Set 12 | necochea
# Processing Record 41 of Set 12 | pula
# Processing Record 42 of Set 12 | makushino
# Processing Record 43 of Set 12 | lahat
# Processing Record 44 of Set 12 | port moresby
# Processing Record 45 of Set 12 | elmont
# Processing Record 46 of Set 12 | uniao da victoria
# City not found. Skipping...
# Processing Record 47 of Set 12 | raudeberg
# Processing Record 48 of Set 12 | cockburn town
# Processing Record 49 of Set 12 | langenau
# Processing Record 50 of Set 12 | la plata
# Processing Record 1 of Set 13 | kysyl-syr
# Processing Record 2 of Set 13 | sinop
# Processing Record 3 of Set 13 | olinda
# Processing Record 4 of Set 13 | shingu
# Processing Record 5 of Set 13 | lishui
# Processing Record 6 of Set 13 | deshnok
# Processing Record 7 of Set 13 | zhigansk
# Processing Record 8 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 9 of Set 13 | omsukchan
# Processing Record 10 of Set 13 | egvekinot
# Processing Record 11 of Set 13 | roebourne
# Processing Record 12 of Set 13 | sobolevo
# Processing Record 13 of Set 13 | merauke
# Processing Record 14 of Set 13 | vestmannaeyjar
# Processing Record 15 of Set 13 | thaba nchu
# Processing Record 16 of Set 13 | qujing
# Processing Record 17 of Set 13 | moindou
# Processing Record 18 of Set 13 | taveta
# Processing Record 19 of Set 13 | acajutla
# Processing Record 20 of Set 13 | tocopilla
# Processing Record 21 of Set 13 | manta
# Processing Record 22 of Set 13 | stoyba
# City not found. Skipping...
# Processing Record 23 of Set 13 | mabaruma
# Processing Record 24 of Set 13 | bereda
# Processing Record 25 of Set 13 | mamontovo
# Processing Record 26 of Set 13 | alyangula
# Processing Record 27 of Set 13 | kruisfontein
# Processing Record 28 of Set 13 | rabo de peixe
# Processing Record 29 of Set 13 | nemuro
# Processing Record 30 of Set 13 | port hawkesbury
# Processing Record 31 of Set 13 | kanniyakumari
# Processing Record 32 of Set 13 | broome
# Processing Record 33 of Set 13 | half moon bay
# Processing Record 34 of Set 13 | mingrelskaya
# Processing Record 35 of Set 13 | ossora
# Processing Record 36 of Set 13 | yangambi
# Processing Record 37 of Set 13 | gravelbourg
# Processing Record 38 of Set 13 | shirochanka
# Processing Record 39 of Set 13 | oranjemund
# Processing Record 40 of Set 13 | lampang
# Processing Record 41 of Set 13 | khingansk
# Processing Record 42 of Set 13 | douglas
# Processing Record 43 of Set 13 | zhanaozen
# Processing Record 44 of Set 13 | ocampo
# Processing Record 45 of Set 13 | hirara
# Processing Record 46 of Set 13 | san vicente
# Processing Record 47 of Set 13 | jinchang
# Processing Record 48 of Set 13 | dafeng
# Processing Record 49 of Set 13 | wanning
# Processing Record 50 of Set 13 | senahu
# Processing Record 1 of Set 14 | katangli
# Processing Record 2 of Set 14 | kavali
# Processing Record 3 of Set 14 | erenhot
# Processing Record 4 of Set 14 | ilhabela
# Processing Record 5 of Set 14 | hobyo
# Processing Record 6 of Set 14 | cajaruro
# Processing Record 7 of Set 14 | pacific grove
# Processing Record 8 of Set 14 | tahta
# Processing Record 9 of Set 14 | san marcos
# Processing Record 10 of Set 14 | itarema
# Processing Record 11 of Set 14 | gimli
# Processing Record 12 of Set 14 | poya
# Processing Record 13 of Set 14 | lafiagi
# Processing Record 14 of Set 14 | grand centre
# City not found. Skipping...
# Processing Record 15 of Set 14 | voh
# Processing Record 16 of Set 14 | luganville
# Processing Record 17 of Set 14 | berdigestyakh
# Processing Record 18 of Set 14 | suruc
# Processing Record 19 of Set 14 | atlantic city
# Processing Record 20 of Set 14 | chipinge
# Processing Record 21 of Set 14 | abonnema
# Processing Record 22 of Set 14 | kunya
# Processing Record 23 of Set 14 | miandrivazo
# Processing Record 24 of Set 14 | popova
# Processing Record 25 of Set 14 | zalantun
# Processing Record 26 of Set 14 | cervo
# Processing Record 27 of Set 14 | biskamzha
# Processing Record 28 of Set 14 | eyrarbakki
# Processing Record 29 of Set 14 | sokoni
# Processing Record 30 of Set 14 | rialma
# Processing Record 31 of Set 14 | saint-pierre
# Processing Record 32 of Set 14 | mnogovershinnyy
# Processing Record 33 of Set 14 | aripuana
# Processing Record 34 of Set 14 | mulanje
# Processing Record 35 of Set 14 | manicore
# Processing Record 36 of Set 14 | bam
# Processing Record 37 of Set 14 | otukpo
# Processing Record 38 of Set 14 | akyab
# Processing Record 39 of Set 14 | novyy urengoy
# Processing Record 40 of Set 14 | ahuimanu
# Processing Record 41 of Set 14 | arlit
# Processing Record 42 of Set 14 | clarence town
# Processing Record 43 of Set 14 | charleston
# Processing Record 44 of Set 14 | lubumbashi
# Processing Record 45 of Set 14 | belturbet
# Processing Record 46 of Set 14 | powell river
# Processing Record 47 of Set 14 | manaure
# Processing Record 48 of Set 14 | salym
# Processing Record 49 of Set 14 | danjiangkou
# Processing Record 50 of Set 14 | mana
# Processing Record 1 of Set 15 | kibala
# Processing Record 2 of Set 15 | lafia
# Processing Record 3 of Set 15 | caldwell
# Processing Record 4 of Set 15 | musoma
# Processing Record 5 of Set 15 | prescott valley
# Processing Record 6 of Set 15 | bilma
# Processing Record 7 of Set 15 | russell
# Processing Record 8 of Set 15 | pittsfield
# Processing Record 9 of Set 15 | west wendover
# Processing Record 10 of Set 15 | opuwo
# Processing Record 11 of Set 15 | pouembout
# Processing Record 12 of Set 15 | smithfield
# Processing Record 13 of Set 15 | umm lajj
# Processing Record 14 of Set 15 | rameswaram
# Processing Record 15 of Set 15 | pachino
# Processing Record 16 of Set 15 | babol
# Processing Record 17 of Set 15 | sungaipenuh
# Processing Record 18 of Set 15 | kroya
# Processing Record 19 of Set 15 | mpanda
# Processing Record 20 of Set 15 | malwan
# City not found. Skipping...
# Processing Record 21 of Set 15 | conceicao do araguaia
# Processing Record 22 of Set 15 | akola
# Processing Record 23 of Set 15 | kolyvan
# Processing Record 24 of Set 15 | katherine
# Processing Record 25 of Set 15 | esso
# Processing Record 26 of Set 15 | lodja
# Processing Record 27 of Set 15 | yar-sale
# Processing Record 28 of Set 15 | metabetchouan
# City not found. Skipping...
# Processing Record 29 of Set 15 | pumiao
# Processing Record 30 of Set 15 | norfolk
# Processing Record 31 of Set 15 | kazalinsk
# City not found. Skipping...
# Processing Record 32 of Set 15 | thunder bay
# Processing Record 33 of Set 15 | trinidad
# Processing Record 34 of Set 15 | vinstra
# Processing Record 35 of Set 15 | guymon
# Processing Record 36 of Set 15 | el vendrell
# Processing Record 37 of Set 15 | ciudad guayana
# Processing Record 38 of Set 15 | redmond
# Processing Record 39 of Set 15 | redlands
# Processing Record 40 of Set 15 | nazarovo
# Processing Record 41 of Set 15 | dargaville
# Processing Record 42 of Set 15 | gawler
# Processing Record 43 of Set 15 | novikovo
# Processing Record 44 of Set 15 | kerman
# Processing Record 45 of Set 15 | okandja
# City not found. Skipping...
# Processing Record 46 of Set 15 | palmer
# Processing Record 47 of Set 15 | dicabisagan
# Processing Record 48 of Set 15 | gravdal
# Processing Record 49 of Set 15 | donghai
# Processing Record 50 of Set 15 | sri aman
# Processing Record 1 of Set 16 | san nicolas
# Processing Record 2 of Set 16 | mountain home
# Processing Record 3 of Set 16 | inderborskiy
# City not found. Skipping...
# Processing Record 4 of Set 16 | tortoli
# Processing Record 5 of Set 16 | maniitsoq
# Processing Record 6 of Set 16 | jumla
# Processing Record 7 of Set 16 | severodvinsk
# Processing Record 8 of Set 16 | reforma
# Processing Record 9 of Set 16 | praya
# Processing Record 10 of Set 16 | kidal
# Processing Record 11 of Set 16 | ilula
# Processing Record 12 of Set 16 | tahlequah
# Processing Record 13 of Set 16 | mogadishu
# Processing Record 14 of Set 16 | awbari
# Processing Record 15 of Set 16 | millville
# Processing Record 16 of Set 16 | acarau
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(cities)
# Out:
# 766

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Puerto Ayora      EC  -0.7393  -90.3518     76.96        86          50
# 1          Albany      US  42.6001  -73.9662     76.87        68          55
# 2        Khatanga      RU  71.9667  102.5000     62.56        67          68
# 3           Tondi      IN   9.7333   79.0167     85.41        66         100
# 4    Port Hedland      AU -20.3167  118.5667     59.05        44           0
# ..            ...     ...      ...       ...       ...       ...         ...
# 702     Tahlequah      US  35.9154  -94.9700     88.84        58          98
# 703     Mogadishu      SO   2.0371   45.3438     75.92        85          76
# 704        Awbari      LY  26.5921   12.7805     93.69         9           0
# 705     Millville      US  39.4021  -75.0393     76.98        82          90
# 706        Acarau      BR  -2.8856  -40.1200     85.32        57          90
#
#      Wind Speed Current Description
# 0          4.00    scattered clouds
# 1          8.10       broken clouds
# 2          8.55       broken clouds
# 3          7.85     overcast clouds
# 4         11.50           clear sky
# ..          ...                 ...
# 702        4.61     overcast clouds
# 703       20.65          light rain
# 704        6.91           clear sky
# 705        4.61       moderate rain
# 706       17.78     overcast clouds
#
# [707 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"

# Export the WeatherPy_Database into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
