# %% [markdown]
# # Deliverable 1: Retrieve Weather Data

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of 2,000 random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Import the citipy module 
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 777

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Build the basic URL for the OpenWeatherMap with your weather_api_key added to the URL
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

#print(url)

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_current_description = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard.
        #city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_current_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")


# Loop through all the cities in our list.
for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + cities[i]
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | fort nelson
# Processing Record 2 of Set 1 | tiksi
# Processing Record 3 of Set 1 | puerto ayora
# Processing Record 4 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 5 of Set 1 | ushuaia
# Processing Record 6 of Set 1 | lompoc
# Processing Record 7 of Set 1 | tasiilaq
# Processing Record 8 of Set 1 | kaitangata
# Processing Record 9 of Set 1 | nyurba
# Processing Record 10 of Set 1 | punta arenas
# Processing Record 11 of Set 1 | burica
# City not found. Skipping...
# Processing Record 12 of Set 1 | jamestown
# Processing Record 13 of Set 1 | xining
# Processing Record 14 of Set 1 | rikitea
# Processing Record 15 of Set 1 | robertsport
# Processing Record 16 of Set 1 | bargal
# City not found. Skipping...
# Processing Record 17 of Set 1 | vilhena
# Processing Record 18 of Set 1 | el retorno
# Processing Record 19 of Set 1 | albany
# Processing Record 20 of Set 1 | new norfolk
# Processing Record 21 of Set 1 | port elizabeth
# Processing Record 22 of Set 1 | pevek
# Processing Record 23 of Set 1 | tuktoyaktuk
# Processing Record 24 of Set 1 | svetlogorsk
# Processing Record 25 of Set 1 | bredasdorp
# Processing Record 26 of Set 1 | urucara
# Processing Record 27 of Set 1 | karamea
# City not found. Skipping...
# Processing Record 28 of Set 1 | avarua
# Processing Record 29 of Set 1 | udachnyy
# Processing Record 30 of Set 1 | ovalle
# Processing Record 31 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 32 of Set 1 | xichang
# Processing Record 33 of Set 1 | carnarvon
# Processing Record 34 of Set 1 | jalu
# Processing Record 35 of Set 1 | port alfred
# Processing Record 36 of Set 1 | yulara
# Processing Record 37 of Set 1 | cape town
# Processing Record 38 of Set 1 | dikson
# Processing Record 39 of Set 1 | kaseda
# Processing Record 40 of Set 1 | dumas
# Processing Record 41 of Set 1 | hithadhoo
# Processing Record 42 of Set 1 | muncar
# Processing Record 43 of Set 1 | atuona
# Processing Record 44 of Set 1 | chuy
# Processing Record 45 of Set 1 | barrow
# Processing Record 46 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 47 of Set 1 | samsun
# Processing Record 48 of Set 1 | sambava
# Processing Record 49 of Set 1 | cherskiy
# Processing Record 50 of Set 1 | busselton
# Processing Record 1 of Set 2 | marienburg
# Processing Record 2 of Set 2 | nikolskoye
# Processing Record 3 of Set 2 | salekhard
# Processing Record 4 of Set 2 | bluff
# Processing Record 5 of Set 2 | shenjiamen
# Processing Record 6 of Set 2 | namibe
# Processing Record 7 of Set 2 | rafai
# Processing Record 8 of Set 2 | antofagasta
# Processing Record 9 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 10 of Set 2 | bambous virieux
# Processing Record 11 of Set 2 | tromso
# Processing Record 12 of Set 2 | barawe
# City not found. Skipping...
# Processing Record 13 of Set 2 | ust-karsk
# Processing Record 14 of Set 2 | vadso
# Processing Record 15 of Set 2 | geraldton
# Processing Record 16 of Set 2 | saskylakh
# Processing Record 17 of Set 2 | hobart
# Processing Record 18 of Set 2 | airai
# Processing Record 19 of Set 2 | mana
# Processing Record 20 of Set 2 | hofn
# Processing Record 21 of Set 2 | andenes
# Processing Record 22 of Set 2 | victoria
# Processing Record 23 of Set 2 | kodiak
# Processing Record 24 of Set 2 | caravelas
# Processing Record 25 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 26 of Set 2 | manbij
# Processing Record 27 of Set 2 | porto novo
# Processing Record 28 of Set 2 | plyussa
# Processing Record 29 of Set 2 | guisijan
# Processing Record 30 of Set 2 | altay
# Processing Record 31 of Set 2 | pisco
# Processing Record 32 of Set 2 | kruisfontein
# Processing Record 33 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 34 of Set 2 | nome
# Processing Record 35 of Set 2 | oranjemund
# Processing Record 36 of Set 2 | suntar
# Processing Record 37 of Set 2 | boende
# Processing Record 38 of Set 2 | qaanaaq
# Processing Record 39 of Set 2 | cockburn town
# Processing Record 40 of Set 2 | galgani
# City not found. Skipping...
# Processing Record 41 of Set 2 | iralaya
# Processing Record 42 of Set 2 | souillac
# Processing Record 43 of Set 2 | bud
# Processing Record 44 of Set 2 | ribeira grande
# Processing Record 45 of Set 2 | port macquarie
# Processing Record 46 of Set 2 | iqaluit
# Processing Record 47 of Set 2 | waipawa
# Processing Record 48 of Set 2 | mataura
# Processing Record 49 of Set 2 | kolyvan
# Processing Record 50 of Set 2 | onega
# Processing Record 1 of Set 3 | saint george
# Processing Record 2 of Set 3 | kabanjahe
# Processing Record 3 of Set 3 | zhigansk
# Processing Record 4 of Set 3 | uni
# Processing Record 5 of Set 3 | kaifeng
# Processing Record 6 of Set 3 | esperance
# Processing Record 7 of Set 3 | sao lourenco do sul
# Processing Record 8 of Set 3 | kapaa
# Processing Record 9 of Set 3 | qesarya
# Processing Record 10 of Set 3 | yerbogachen
# Processing Record 11 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 12 of Set 3 | ancud
# Processing Record 13 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 14 of Set 3 | rio gallegos
# Processing Record 15 of Set 3 | saint-philippe
# Processing Record 16 of Set 3 | butaritari
# Processing Record 17 of Set 3 | dawlatabad
# Processing Record 18 of Set 3 | upernavik
# Processing Record 19 of Set 3 | tall kayf
# Processing Record 20 of Set 3 | atar
# Processing Record 21 of Set 3 | mahebourg
# Processing Record 22 of Set 3 | zhangjiakou
# Processing Record 23 of Set 3 | tiarei
# Processing Record 24 of Set 3 | vylkove
# Processing Record 25 of Set 3 | ramsar
# Processing Record 26 of Set 3 | porto torres
# Processing Record 27 of Set 3 | vaini
# Processing Record 28 of Set 3 | mariakani
# Processing Record 29 of Set 3 | fortuna
# Processing Record 30 of Set 3 | takhli
# Processing Record 31 of Set 3 | chapleau
# Processing Record 32 of Set 3 | tadine
# Processing Record 33 of Set 3 | chokurdakh
# Processing Record 34 of Set 3 | bani
# Processing Record 35 of Set 3 | adrar
# Processing Record 36 of Set 3 | arraial do cabo
# Processing Record 37 of Set 3 | yellowknife
# Processing Record 38 of Set 3 | berezovyy
# Processing Record 39 of Set 3 | bethel
# Processing Record 40 of Set 3 | beisfjord
# Processing Record 41 of Set 3 | laviana
# Processing Record 42 of Set 3 | kaeo
# Processing Record 43 of Set 3 | lodwar
# Processing Record 44 of Set 3 | guiuan
# Processing Record 45 of Set 3 | ami
# Processing Record 46 of Set 3 | grand centre
# City not found. Skipping...
# Processing Record 47 of Set 3 | bagdarin
# Processing Record 48 of Set 3 | kirkenes
# Processing Record 49 of Set 3 | egvekinot
# Processing Record 50 of Set 3 | lagoa
# Processing Record 1 of Set 4 | coahuayana
# Processing Record 2 of Set 4 | mizdah
# Processing Record 3 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 4 of Set 4 | isangel
# Processing Record 5 of Set 4 | jinchang
# Processing Record 6 of Set 4 | naze
# Processing Record 7 of Set 4 | hilo
# Processing Record 8 of Set 4 | svetlaya
# Processing Record 9 of Set 4 | senno
# Processing Record 10 of Set 4 | yantal
# Processing Record 11 of Set 4 | xai-xai
# Processing Record 12 of Set 4 | awjilah
# Processing Record 13 of Set 4 | muros
# Processing Record 14 of Set 4 | talcahuano
# Processing Record 15 of Set 4 | bubaque
# Processing Record 16 of Set 4 | fairbanks
# Processing Record 17 of Set 4 | alamosa
# Processing Record 18 of Set 4 | hasaki
# Processing Record 19 of Set 4 | torbay
# Processing Record 20 of Set 4 | hermanus
# Processing Record 21 of Set 4 | khatanga
# Processing Record 22 of Set 4 | margate
# Processing Record 23 of Set 4 | nouadhibou
# Processing Record 24 of Set 4 | palamos
# Processing Record 25 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 26 of Set 4 | vestmannaeyjar
# Processing Record 27 of Set 4 | hearst
# Processing Record 28 of Set 4 | thompson
# Processing Record 29 of Set 4 | beringovskiy
# Processing Record 30 of Set 4 | louisbourg
# City not found. Skipping...
# Processing Record 31 of Set 4 | provideniya
# Processing Record 32 of Set 4 | dakar
# Processing Record 33 of Set 4 | camocim
# Processing Record 34 of Set 4 | vanimo
# Processing Record 35 of Set 4 | abu jubayhah
# City not found. Skipping...
# Processing Record 36 of Set 4 | healdsburg
# Processing Record 37 of Set 4 | vostok
# Processing Record 38 of Set 4 | trelew
# Processing Record 39 of Set 4 | cidreira
# Processing Record 40 of Set 4 | mar del plata
# Processing Record 41 of Set 4 | farah
# Processing Record 42 of Set 4 | karratha
# Processing Record 43 of Set 4 | solton
# Processing Record 44 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 45 of Set 4 | thunder bay
# Processing Record 46 of Set 4 | la huaca
# Processing Record 47 of Set 4 | asau
# Processing Record 48 of Set 4 | puerto leguizamo
# Processing Record 49 of Set 4 | gonbad-e qabus
# Processing Record 50 of Set 4 | labuhan
# Processing Record 1 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 2 of Set 5 | east london
# Processing Record 3 of Set 5 | bara
# Processing Record 4 of Set 5 | castro
# Processing Record 5 of Set 5 | san cristobal
# Processing Record 6 of Set 5 | sosnovo-ozerskoye
# Processing Record 7 of Set 5 | calvinia
# Processing Record 8 of Set 5 | port lincoln
# Processing Record 9 of Set 5 | eschwege
# Processing Record 10 of Set 5 | antalaha
# Processing Record 11 of Set 5 | lebu
# Processing Record 12 of Set 5 | marzuq
# Processing Record 13 of Set 5 | nangong
# Processing Record 14 of Set 5 | mullaitivu
# City not found. Skipping...
# Processing Record 15 of Set 5 | axim
# Processing Record 16 of Set 5 | nhulunbuy
# Processing Record 17 of Set 5 | verkhoyansk
# Processing Record 18 of Set 5 | salalah
# Processing Record 19 of Set 5 | awbari
# Processing Record 20 of Set 5 | acapulco
# Processing Record 21 of Set 5 | bendigo
# Processing Record 22 of Set 5 | newport beach
# Processing Record 23 of Set 5 | norman wells
# Processing Record 24 of Set 5 | kang
# Processing Record 25 of Set 5 | narsaq
# Processing Record 26 of Set 5 | kavaratti
# Processing Record 27 of Set 5 | ponta do sol
# Processing Record 28 of Set 5 | kalat
# Processing Record 29 of Set 5 | ngukurr
# City not found. Skipping...
# Processing Record 30 of Set 5 | ust-maya
# Processing Record 31 of Set 5 | broome
# Processing Record 32 of Set 5 | sur
# Processing Record 33 of Set 5 | palafrugell
# Processing Record 34 of Set 5 | ormara
# Processing Record 35 of Set 5 | sitka
# Processing Record 36 of Set 5 | surovikino
# Processing Record 37 of Set 5 | tashtagol
# Processing Record 38 of Set 5 | araceli
# Processing Record 39 of Set 5 | sept-iles
# Processing Record 40 of Set 5 | tarko-sale
# Processing Record 41 of Set 5 | ilulissat
# Processing Record 42 of Set 5 | mayor pablo lagerenza
# Processing Record 43 of Set 5 | portalegre
# Processing Record 44 of Set 5 | akyab
# Processing Record 45 of Set 5 | ewa beach
# Processing Record 46 of Set 5 | nanortalik
# Processing Record 47 of Set 5 | saurimo
# Processing Record 48 of Set 5 | surt
# Processing Record 49 of Set 5 | carauari
# Processing Record 50 of Set 5 | barranca
# Processing Record 1 of Set 6 | georgetown
# Processing Record 2 of Set 6 | alofi
# Processing Record 3 of Set 6 | siddipet
# Processing Record 4 of Set 6 | viedma
# Processing Record 5 of Set 6 | constitucion
# Processing Record 6 of Set 6 | vallenar
# Processing Record 7 of Set 6 | gushikawa
# Processing Record 8 of Set 6 | santa cruz
# Processing Record 9 of Set 6 | shanhetun
# Processing Record 10 of Set 6 | ketchikan
# Processing Record 11 of Set 6 | qinhuangdao
# Processing Record 12 of Set 6 | jumla
# Processing Record 13 of Set 6 | vila franca do campo
# Processing Record 14 of Set 6 | mount isa
# Processing Record 15 of Set 6 | boali
# Processing Record 16 of Set 6 | zhanatas
# City not found. Skipping...
# Processing Record 17 of Set 6 | maniitsoq
# Processing Record 18 of Set 6 | paamiut
# Processing Record 19 of Set 6 | faya
# Processing Record 20 of Set 6 | solsvik
# City not found. Skipping...
# Processing Record 21 of Set 6 | benghazi
# Processing Record 22 of Set 6 | aflu
# City not found. Skipping...
# Processing Record 23 of Set 6 | aklavik
# Processing Record 24 of Set 6 | ushibuka
# Processing Record 25 of Set 6 | westport
# Processing Record 26 of Set 6 | lacdayan
# Processing Record 27 of Set 6 | port hardy
# Processing Record 28 of Set 6 | byron bay
# Processing Record 29 of Set 6 | isiro
# Processing Record 30 of Set 6 | kofarnihon
# City not found. Skipping...
# Processing Record 31 of Set 6 | dingle
# Processing Record 32 of Set 6 | san rafael
# Processing Record 33 of Set 6 | arica
# Processing Record 34 of Set 6 | luderitz
# Processing Record 35 of Set 6 | tarsus
# Processing Record 36 of Set 6 | bria
# Processing Record 37 of Set 6 | malkara
# Processing Record 38 of Set 6 | henties bay
# Processing Record 39 of Set 6 | talara
# Processing Record 40 of Set 6 | havre-saint-pierre
# Processing Record 41 of Set 6 | touros
# Processing Record 42 of Set 6 | shimoda
# Processing Record 43 of Set 6 | rayadrug
# Processing Record 44 of Set 6 | coihaique
# Processing Record 45 of Set 6 | tabulbah
# City not found. Skipping...
# Processing Record 46 of Set 6 | kabare
# Processing Record 47 of Set 6 | half moon bay
# Processing Record 48 of Set 6 | uniara
# Processing Record 49 of Set 6 | tiznit
# Processing Record 50 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 1 of Set 7 | sao joao do piaui
# Processing Record 2 of Set 7 | katsuura
# Processing Record 3 of Set 7 | belmonte
# Processing Record 4 of Set 7 | brunsbuttel
# Processing Record 5 of Set 7 | mitu
# Processing Record 6 of Set 7 | pangnirtung
# Processing Record 7 of Set 7 | grand forks
# Processing Record 8 of Set 7 | guerrero negro
# Processing Record 9 of Set 7 | laguna
# Processing Record 10 of Set 7 | los llanos de aridane
# Processing Record 11 of Set 7 | faanui
# Processing Record 12 of Set 7 | gualan
# Processing Record 13 of Set 7 | nago
# Processing Record 14 of Set 7 | porto santo
# Processing Record 15 of Set 7 | viligili
# City not found. Skipping...
# Processing Record 16 of Set 7 | sao miguel do araguaia
# Processing Record 17 of Set 7 | calderitas
# Processing Record 18 of Set 7 | babushkin
# Processing Record 19 of Set 7 | pitimbu
# Processing Record 20 of Set 7 | luganville
# Processing Record 21 of Set 7 | beloha
# Processing Record 22 of Set 7 | zhezkazgan
# Processing Record 23 of Set 7 | umm kaddadah
# Processing Record 24 of Set 7 | poum
# Processing Record 25 of Set 7 | gamba
# Processing Record 26 of Set 7 | kitwe
# Processing Record 27 of Set 7 | skibbereen
# Processing Record 28 of Set 7 | tilichiki
# Processing Record 29 of Set 7 | hammerfest
# Processing Record 30 of Set 7 | flinders
# Processing Record 31 of Set 7 | bonavista
# Processing Record 32 of Set 7 | srednekolymsk
# Processing Record 33 of Set 7 | malakal
# Processing Record 34 of Set 7 | tsabong
# Processing Record 35 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 36 of Set 7 | tuntum
# Processing Record 37 of Set 7 | rengasdengklok
# Processing Record 38 of Set 7 | ambon
# Processing Record 39 of Set 7 | longyearbyen
# Processing Record 40 of Set 7 | saldanha
# Processing Record 41 of Set 7 | kindu
# Processing Record 42 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 43 of Set 7 | pontianak
# Processing Record 44 of Set 7 | pacific grove
# Processing Record 45 of Set 7 | sao filipe
# Processing Record 46 of Set 7 | perpignan
# Processing Record 47 of Set 7 | navapur
# City not found. Skipping...
# Processing Record 48 of Set 7 | san juan
# Processing Record 49 of Set 7 | kurumkan
# Processing Record 50 of Set 7 | la ronge
# Processing Record 1 of Set 8 | kingman
# Processing Record 2 of Set 8 | homer
# Processing Record 3 of Set 8 | fox lake
# Processing Record 4 of Set 8 | teguise
# Processing Record 5 of Set 8 | miles city
# Processing Record 6 of Set 8 | sterling
# Processing Record 7 of Set 8 | otofuke
# Processing Record 8 of Set 8 | clyde river
# Processing Record 9 of Set 8 | oriximina
# Processing Record 10 of Set 8 | dalen
# Processing Record 11 of Set 8 | westpunt
# City not found. Skipping...
# Processing Record 12 of Set 8 | atbasar
# Processing Record 13 of Set 8 | sola
# Processing Record 14 of Set 8 | mezen
# Processing Record 15 of Set 8 | makakilo city
# Processing Record 16 of Set 8 | ostrovnoy
# Processing Record 17 of Set 8 | kadykchan
# City not found. Skipping...
# Processing Record 18 of Set 8 | turukhansk
# Processing Record 19 of Set 8 | songjianghe
# Processing Record 20 of Set 8 | san patricio
# Processing Record 21 of Set 8 | siyana
# Processing Record 22 of Set 8 | bima
# Processing Record 23 of Set 8 | tongzi
# Processing Record 24 of Set 8 | tuensang
# Processing Record 25 of Set 8 | terre haute
# Processing Record 26 of Set 8 | pangoa
# Processing Record 27 of Set 8 | phan thiet
# Processing Record 28 of Set 8 | arrifes
# Processing Record 29 of Set 8 | guatire
# Processing Record 30 of Set 8 | sun valley
# Processing Record 31 of Set 8 | pogar
# Processing Record 32 of Set 8 | hovd
# Processing Record 33 of Set 8 | ulladulla
# Processing Record 34 of Set 8 | mazatlan
# Processing Record 35 of Set 8 | mamakan
# Processing Record 36 of Set 8 | coquimbo
# Processing Record 37 of Set 8 | chimoio
# Processing Record 38 of Set 8 | fort abbas
# Processing Record 39 of Set 8 | sabang
# Processing Record 40 of Set 8 | talnakh
# Processing Record 41 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 42 of Set 8 | marathon
# Processing Record 43 of Set 8 | dzhusaly
# City not found. Skipping...
# Processing Record 44 of Set 8 | port blair
# Processing Record 45 of Set 8 | gat
# Processing Record 46 of Set 8 | leningradskiy
# Processing Record 47 of Set 8 | nantucket
# Processing Record 48 of Set 8 | olafsvik
# Processing Record 49 of Set 8 | pilar
# Processing Record 50 of Set 8 | klaksvik
# Processing Record 1 of Set 9 | prainha
# Processing Record 2 of Set 9 | suvorovo
# Processing Record 3 of Set 9 | kjollefjord
# Processing Record 4 of Set 9 | troy
# Processing Record 5 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 6 of Set 9 | galveston
# Processing Record 7 of Set 9 | samarai
# Processing Record 8 of Set 9 | otane
# Processing Record 9 of Set 9 | grand-santi
# Processing Record 10 of Set 9 | coruripe
# Processing Record 11 of Set 9 | fecamp
# Processing Record 12 of Set 9 | valasske klobouky
# Processing Record 13 of Set 9 | walvis bay
# Processing Record 14 of Set 9 | bokovskaya
# Processing Record 15 of Set 9 | ardistan
# City not found. Skipping...
# Processing Record 16 of Set 9 | codrington
# Processing Record 17 of Set 9 | chernyshevsk
# Processing Record 18 of Set 9 | dunedin
# Processing Record 19 of Set 9 | dalbandin
# Processing Record 20 of Set 9 | nizwa
# Processing Record 21 of Set 9 | mirnyy
# Processing Record 22 of Set 9 | marquette
# Processing Record 23 of Set 9 | tabuk
# Processing Record 24 of Set 9 | san-pedro
# Processing Record 25 of Set 9 | tessalit
# Processing Record 26 of Set 9 | tuatapere
# Processing Record 27 of Set 9 | ranikhet
# Processing Record 28 of Set 9 | belaya gora
# Processing Record 29 of Set 9 | asyut
# Processing Record 30 of Set 9 | college
# Processing Record 31 of Set 9 | vaitape
# Processing Record 32 of Set 9 | krasnoselkup
# Processing Record 33 of Set 9 | grindavik
# Processing Record 34 of Set 9 | superior
# Processing Record 35 of Set 9 | phek
# Processing Record 36 of Set 9 | ipixuna
# Processing Record 37 of Set 9 | terra nova
# Processing Record 38 of Set 9 | irbeyskoye
# Processing Record 39 of Set 9 | ikungi
# Processing Record 40 of Set 9 | san quintin
# Processing Record 41 of Set 9 | filadelfia
# Processing Record 42 of Set 9 | evensk
# Processing Record 43 of Set 9 | sinnamary
# Processing Record 44 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 45 of Set 9 | ndjole
# Processing Record 46 of Set 9 | saint-pierre
# Processing Record 47 of Set 9 | rakhya
# City not found. Skipping...
# Processing Record 48 of Set 9 | stawell
# Processing Record 49 of Set 9 | bobrovytsya
# Processing Record 50 of Set 9 | petatlan
# Processing Record 1 of Set 10 | deputatskiy
# Processing Record 2 of Set 10 | dalby
# Processing Record 3 of Set 10 | keti bandar
# Processing Record 4 of Set 10 | gaur
# Processing Record 5 of Set 10 | bumba
# Processing Record 6 of Set 10 | kenai
# Processing Record 7 of Set 10 | marrakesh
# Processing Record 8 of Set 10 | dickinson
# Processing Record 9 of Set 10 | zemio
# Processing Record 10 of Set 10 | mnogovershinnyy
# Processing Record 11 of Set 10 | husavik
# Processing Record 12 of Set 10 | capim grosso
# Processing Record 13 of Set 10 | kadoma
# Processing Record 14 of Set 10 | te anau
# Processing Record 15 of Set 10 | irbil
# Processing Record 16 of Set 10 | merrill
# Processing Record 17 of Set 10 | grand gaube
# Processing Record 18 of Set 10 | vardo
# Processing Record 19 of Set 10 | itarema
# Processing Record 20 of Set 10 | bhuj
# Processing Record 21 of Set 10 | harlingen
# Processing Record 22 of Set 10 | nelson bay
# Processing Record 23 of Set 10 | karlshamn
# Processing Record 24 of Set 10 | tlacotepec
# Processing Record 25 of Set 10 | kununurra
# Processing Record 26 of Set 10 | sao joao do paraiso
# Processing Record 27 of Set 10 | cabedelo
# Processing Record 28 of Set 10 | lufilufi
# Processing Record 29 of Set 10 | lavrentiya
# Processing Record 30 of Set 10 | xunchang
# Processing Record 31 of Set 10 | salinopolis
# Processing Record 32 of Set 10 | kencong
# Processing Record 33 of Set 10 | bengkulu
# Processing Record 34 of Set 10 | hobyo
# Processing Record 35 of Set 10 | mayo
# Processing Record 36 of Set 10 | charters towers
# Processing Record 37 of Set 10 | vaitupu
# City not found. Skipping...
# Processing Record 38 of Set 10 | amahai
# Processing Record 39 of Set 10 | oistins
# Processing Record 40 of Set 10 | minsk
# Processing Record 41 of Set 10 | mouzakion
# City not found. Skipping...
# Processing Record 42 of Set 10 | shingu
# Processing Record 43 of Set 10 | manzil tamim
# City not found. Skipping...
# Processing Record 44 of Set 10 | avera
# Processing Record 45 of Set 10 | guangyuan
# Processing Record 46 of Set 10 | luquillo
# Processing Record 47 of Set 10 | agirish
# Processing Record 48 of Set 10 | kapit
# Processing Record 49 of Set 10 | yumen
# Processing Record 50 of Set 10 | cabo san lucas
# Processing Record 1 of Set 11 | phuket
# Processing Record 2 of Set 11 | corn island
# Processing Record 3 of Set 11 | sivas
# Processing Record 4 of Set 11 | kroya
# Processing Record 5 of Set 11 | innisfail
# Processing Record 6 of Set 11 | fare
# Processing Record 7 of Set 11 | ust-kuyga
# Processing Record 8 of Set 11 | ondorhaan
# City not found. Skipping...
# Processing Record 9 of Set 11 | sibolga
# Processing Record 10 of Set 11 | haines junction
# Processing Record 11 of Set 11 | ribeira do pombal
# Processing Record 12 of Set 11 | chicla
# Processing Record 13 of Set 11 | omsukchan
# Processing Record 14 of Set 11 | kalmunai
# Processing Record 15 of Set 11 | san jeronimo
# Processing Record 16 of Set 11 | vryheid
# Processing Record 17 of Set 11 | sorland
# Processing Record 18 of Set 11 | kahului
# Processing Record 19 of Set 11 | sekoma
# Processing Record 20 of Set 11 | birao
# Processing Record 21 of Set 11 | north bend
# Processing Record 22 of Set 11 | dongsheng
# Processing Record 23 of Set 11 | bay roberts
# Processing Record 24 of Set 11 | pimentel
# Processing Record 25 of Set 11 | northam
# Processing Record 26 of Set 11 | odienne
# Processing Record 27 of Set 11 | fougamou
# Processing Record 28 of Set 11 | bhatkal
# Processing Record 29 of Set 11 | vyshneve
# Processing Record 30 of Set 11 | xihe
# Processing Record 31 of Set 11 | jiwani
# Processing Record 32 of Set 11 | sokoto
# Processing Record 33 of Set 11 | lianran
# Processing Record 34 of Set 11 | taoudenni
# Processing Record 35 of Set 11 | beyneu
# Processing Record 36 of Set 11 | pohrebyshche
# Processing Record 37 of Set 11 | joensuu
# Processing Record 38 of Set 11 | tidore
# City not found. Skipping...
# Processing Record 39 of Set 11 | severo-kurilsk
# Processing Record 40 of Set 11 | hualmay
# Processing Record 41 of Set 11 | kletnya
# Processing Record 42 of Set 11 | samalaeulu
# City not found. Skipping...
# Processing Record 43 of Set 11 | mahibadhoo
# Processing Record 44 of Set 11 | qena
# Processing Record 45 of Set 11 | kachiry
# Processing Record 46 of Set 11 | kijang
# Processing Record 47 of Set 11 | barcelona
# Processing Record 48 of Set 11 | luba
# Processing Record 49 of Set 11 | halalo
# City not found. Skipping...
# Processing Record 50 of Set 11 | lovozero
# Processing Record 1 of Set 12 | padang
# Processing Record 2 of Set 12 | mirador
# Processing Record 3 of Set 12 | jujuy
# City not found. Skipping...
# Processing Record 4 of Set 12 | banda aceh
# Processing Record 5 of Set 12 | soe
# Processing Record 6 of Set 12 | kendari
# Processing Record 7 of Set 12 | ayia marina
# Processing Record 8 of Set 12 | doctor juan manuel frutos
# Processing Record 9 of Set 12 | formoso do araguaia
# City not found. Skipping...
# Processing Record 10 of Set 12 | umm lajj
# Processing Record 11 of Set 12 | alekseyevsk
# Processing Record 12 of Set 12 | rio branco
# Processing Record 13 of Set 12 | camacha
# Processing Record 14 of Set 12 | natal
# Processing Record 15 of Set 12 | lorengau
# Processing Record 16 of Set 12 | dolores
# Processing Record 17 of Set 12 | sisimiut
# Processing Record 18 of Set 12 | kuah
# Processing Record 19 of Set 12 | bilibino
# Processing Record 20 of Set 12 | aranda de duero
# Processing Record 21 of Set 12 | mareeba
# Processing Record 22 of Set 12 | stepnyak
# Processing Record 23 of Set 12 | mangalia
# Processing Record 24 of Set 12 | ambilobe
# Processing Record 25 of Set 12 | yaounde
# Processing Record 26 of Set 12 | przasnysz
# Processing Record 27 of Set 12 | la peca
# Processing Record 28 of Set 12 | anadyr
# Processing Record 29 of Set 12 | wulanhaote
# City not found. Skipping...
# Processing Record 30 of Set 12 | cairns
# Processing Record 31 of Set 12 | annonay
# Processing Record 32 of Set 12 | tasbuget
# City not found. Skipping...
# Processing Record 33 of Set 12 | ostrow mazowiecka
# Processing Record 34 of Set 12 | benguela
# Processing Record 35 of Set 12 | shubarkuduk
# Processing Record 36 of Set 12 | yanam
# Processing Record 37 of Set 12 | leamington
# Processing Record 38 of Set 12 | mirpur khas
# Processing Record 39 of Set 12 | concepcion
# Processing Record 40 of Set 12 | dongying
# Processing Record 41 of Set 12 | acarau
# Processing Record 42 of Set 12 | guiratinga
# Processing Record 43 of Set 12 | san juan bautista
# Processing Record 44 of Set 12 | umm ruwabah
# City not found. Skipping...
# Processing Record 45 of Set 12 | havelock
# Processing Record 46 of Set 12 | rafsanjan
# Processing Record 47 of Set 12 | barreirinhas
# Processing Record 48 of Set 12 | marsa matruh
# Processing Record 49 of Set 12 | alta floresta
# Processing Record 50 of Set 12 | hashtrud
# Processing Record 1 of Set 13 | guigue
# Processing Record 2 of Set 13 | usinsk
# Processing Record 3 of Set 13 | kapoeta
# Processing Record 4 of Set 13 | mehamn
# Processing Record 5 of Set 13 | jiangyou
# Processing Record 6 of Set 13 | harper
# Processing Record 7 of Set 13 | sakakah
# Processing Record 8 of Set 13 | cedar city
# Processing Record 9 of Set 13 | suleja
# Processing Record 10 of Set 13 | tucupita
# Processing Record 11 of Set 13 | tres arroyos
# Processing Record 12 of Set 13 | maragogi
# Processing Record 13 of Set 13 | oxilithos
# Processing Record 14 of Set 13 | turtkul
# City not found. Skipping...
# Processing Record 15 of Set 13 | bahir dar
# Processing Record 16 of Set 13 | kavieng
# Processing Record 17 of Set 13 | ankeny
# Processing Record 18 of Set 13 | portachuelo
# Processing Record 19 of Set 13 | nalut
# Processing Record 20 of Set 13 | bulgan
# Processing Record 21 of Set 13 | nongan
# Processing Record 22 of Set 13 | yeniseysk
# Processing Record 23 of Set 13 | komsomolskiy
# Processing Record 24 of Set 13 | tenenkou
# Processing Record 25 of Set 13 | bereda
# Processing Record 26 of Set 13 | tarauaca
# Processing Record 27 of Set 13 | kalomo
# City not found. Skipping...
# Processing Record 28 of Set 13 | florida
# Processing Record 29 of Set 13 | ossora
# Processing Record 30 of Set 13 | okha
# Processing Record 31 of Set 13 | turka
# Processing Record 32 of Set 13 | papetoai
# Processing Record 33 of Set 13 | sampit
# Processing Record 34 of Set 13 | tambovka
# Processing Record 35 of Set 13 | ekhabi
# Processing Record 36 of Set 13 | warqla
# City not found. Skipping...
# Processing Record 37 of Set 13 | kyshtovka
# Processing Record 38 of Set 13 | san joaquin
# Processing Record 39 of Set 13 | dowa
# Processing Record 40 of Set 13 | saryshagan
# City not found. Skipping...
# Processing Record 41 of Set 13 | kenora
# Processing Record 42 of Set 13 | berlevag
# Processing Record 43 of Set 13 | raga
# Processing Record 44 of Set 13 | rzhyshchiv
# Processing Record 45 of Set 13 | bako
# Processing Record 46 of Set 13 | korla
# Processing Record 47 of Set 13 | hamilton
# Processing Record 48 of Set 13 | matay
# Processing Record 49 of Set 13 | mazagao
# Processing Record 50 of Set 13 | terney
# Processing Record 1 of Set 14 | alakurtti
# Processing Record 2 of Set 14 | orhei
# Processing Record 3 of Set 14 | george
# Processing Record 4 of Set 14 | ligayan
# Processing Record 5 of Set 14 | xuzhou
# Processing Record 6 of Set 14 | rennes
# Processing Record 7 of Set 14 | am timan
# Processing Record 8 of Set 14 | aldan
# Processing Record 9 of Set 14 | cayenne
# Processing Record 10 of Set 14 | pampierstad
# Processing Record 11 of Set 14 | mentok
# City not found. Skipping...
# Processing Record 12 of Set 14 | nador
# Processing Record 13 of Set 14 | mogadishu
# Processing Record 14 of Set 14 | quesnel
# Processing Record 15 of Set 14 | manoel urbano
# Processing Record 16 of Set 14 | arlit
# Processing Record 17 of Set 14 | praia da vitoria
# Processing Record 18 of Set 14 | snasa
# Processing Record 19 of Set 14 | chaa-khol
# City not found. Skipping...
# Processing Record 20 of Set 14 | moindou
# Processing Record 21 of Set 14 | aljezur
# Processing Record 22 of Set 14 | hami
# Processing Record 23 of Set 14 | nautla
# Processing Record 24 of Set 14 | prince rupert
# Processing Record 25 of Set 14 | sabzevar
# Processing Record 26 of Set 14 | los reyes
# Processing Record 27 of Set 14 | riverton
# Processing Record 28 of Set 14 | kotlas
# Processing Record 29 of Set 14 | bandarbeyla
# Processing Record 30 of Set 14 | kysyl-syr
# Processing Record 31 of Set 14 | ternate
# Processing Record 32 of Set 14 | madang
# Processing Record 33 of Set 14 | brightwater
# Processing Record 34 of Set 14 | tera
# Processing Record 35 of Set 14 | samfya
# Processing Record 36 of Set 14 | khasan
# Processing Record 37 of Set 14 | mecca
# Processing Record 38 of Set 14 | nemuro
# Processing Record 39 of Set 14 | cuenca
# Processing Record 40 of Set 14 | altagracia de orituco
# Processing Record 41 of Set 14 | saint-joseph
# Processing Record 42 of Set 14 | manakara
# Processing Record 43 of Set 14 | alice springs
# Processing Record 44 of Set 14 | moche
# Processing Record 45 of Set 14 | sandwick
# Processing Record 46 of Set 14 | montepuez
# Processing Record 47 of Set 14 | chadan
# Processing Record 48 of Set 14 | lichinga
# Processing Record 49 of Set 14 | sinkat
# City not found. Skipping...
# Processing Record 50 of Set 14 | kongolo
# Processing Record 1 of Set 15 | alyangula
# Processing Record 2 of Set 15 | shirokiy
# Processing Record 3 of Set 15 | tlalchapa
# Processing Record 4 of Set 15 | flin flon
# Processing Record 5 of Set 15 | daxian
# City not found. Skipping...
# Processing Record 6 of Set 15 | broken hill
# Processing Record 7 of Set 15 | ghanzi
# Processing Record 8 of Set 15 | pindwara
# Processing Record 9 of Set 15 | batemans bay
# Processing Record 10 of Set 15 | shelburne
# Processing Record 11 of Set 15 | mahon
# Processing Record 12 of Set 15 | lata
# Processing Record 13 of Set 15 | penzance
# Processing Record 14 of Set 15 | nishihara
# Processing Record 15 of Set 15 | melilla
# Processing Record 16 of Set 15 | ferkessedougou
# Processing Record 17 of Set 15 | atambua
# Processing Record 18 of Set 15 | bolshoye sorokino
# City not found. Skipping...
# Processing Record 19 of Set 15 | tingrela
# City not found. Skipping...
# Processing Record 20 of Set 15 | shumskiy
# Processing Record 21 of Set 15 | jesus del monte
# Processing Record 22 of Set 15 | portland
# Processing Record 23 of Set 15 | luwuk
# Processing Record 24 of Set 15 | muborak
# Processing Record 25 of Set 15 | carballo
# Processing Record 26 of Set 15 | gambela
# Processing Record 27 of Set 15 | jiexiu
# Processing Record 28 of Set 15 | galle
# Processing Record 29 of Set 15 | bela
# Processing Record 30 of Set 15 | presidencia roque saenz pena
# Processing Record 31 of Set 15 | guilin
# Processing Record 32 of Set 15 | rostusa
# Processing Record 33 of Set 15 | henderson
# Processing Record 34 of Set 15 | calatayud
# Processing Record 35 of Set 15 | angoche
# Processing Record 36 of Set 15 | whitehorse
# Processing Record 37 of Set 15 | rawson
# Processing Record 38 of Set 15 | lumberton
# Processing Record 39 of Set 15 | whitecourt
# Processing Record 40 of Set 15 | nanacamilpa
# Processing Record 41 of Set 15 | kayes
# Processing Record 42 of Set 15 | ust-kut
# Processing Record 43 of Set 15 | palu
# Processing Record 44 of Set 15 | saint pete beach
# Processing Record 45 of Set 15 | brae
# Processing Record 46 of Set 15 | kiama
# Processing Record 47 of Set 15 | bathsheba
# Processing Record 48 of Set 15 | lupiro
# Processing Record 49 of Set 15 | necochea
# Processing Record 50 of Set 15 | wakkanai
# Processing Record 1 of Set 16 | pringsewu
# Processing Record 2 of Set 16 | tumannyy
# City not found. Skipping...
# Processing Record 3 of Set 16 | srivardhan
# Processing Record 4 of Set 16 | namatanai
# Processing Record 5 of Set 16 | barstow
# Processing Record 6 of Set 16 | jubayl
# City not found. Skipping...
# Processing Record 7 of Set 16 | parede
# Processing Record 8 of Set 16 | aitape
# Processing Record 9 of Set 16 | omboue
# Processing Record 10 of Set 16 | lakselv
# Processing Record 11 of Set 16 | vila velha
# Processing Record 12 of Set 16 | alaca
# Processing Record 13 of Set 16 | tommot
# Processing Record 14 of Set 16 | panzhihua
# Processing Record 15 of Set 16 | halifax
# Processing Record 16 of Set 16 | kutum
# Processing Record 17 of Set 16 | shellbrook
# Processing Record 18 of Set 16 | murgab
# Processing Record 19 of Set 16 | aswan
# Processing Record 20 of Set 16 | arona
# Processing Record 21 of Set 16 | la rioja
# Processing Record 22 of Set 16 | dzerzhinsk
# Processing Record 23 of Set 16 | ahipara
# Processing Record 24 of Set 16 | melfi
# Processing Record 25 of Set 16 | itoman
# Processing Record 26 of Set 16 | ixtapa
# Processing Record 27 of Set 16 | tabou
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(cities)
# Out:
# 777

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Fort Nelson      CA  58.8053 -122.7002     93.15        25           0
# 1           Tiksi      RU  71.6872  128.8694     51.28        65          31
# 2    Puerto Ayora      EC  -0.7393  -90.3518     69.55        94          42
# 3         Ushuaia      AR -54.8000  -68.3000     38.86        81          75
# 4          Lompoc      US  34.6391 -120.4579     85.57        65           1
# ..            ...     ...      ...       ...       ...       ...         ...
# 709       Ahipara      NZ -35.1667  173.1667     58.26        67          13
# 710         Melfi      IT  40.9965   15.6514     76.23        60           4
# 711        Itoman      JP  26.1247  127.6694     86.38        91          75
# 712        Ixtapa      MX  20.7000 -105.2000     87.22        70          75
# 713         Tabou      CI   4.4230   -7.3528     76.23        81          96
#
#      Wind Speed Current Description
# 0          3.04           clear sky
# 1          6.22    scattered clouds
# 2          5.01    scattered clouds
# 3         11.50       broken clouds
# 4         12.66           clear sky
# ..          ...                 ...
# 709       11.56          few clouds
# 710        8.08           clear sky
# 711       17.27       broken clouds
# 712       11.50       broken clouds
# 713        6.29     overcast clouds
#
# [714 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "../Weather_Database/WeatherPy_Database.csv"

# Export the WeatherPy_Database into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
