# %% [markdown]
# # Deliverable 1: Retrieve Weather Data

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of 2,000 random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Import the citipy module 
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 753

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Build the basic URL for the OpenWeatherMap with your weather_api_key added to the URL
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

#print(url)

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_current_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        #city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_current_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")


# Loop through all the cities in our list.
for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + cities[i]
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ushuaia
# Processing Record 2 of Set 1 | port blair
# Processing Record 3 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 4 of Set 1 | tuktoyaktuk
# Processing Record 5 of Set 1 | radford
# Processing Record 6 of Set 1 | guerrero negro
# Processing Record 7 of Set 1 | kaitangata
# Processing Record 8 of Set 1 | poum
# Processing Record 9 of Set 1 | kahului
# Processing Record 10 of Set 1 | tiksi
# Processing Record 11 of Set 1 | avarua
# Processing Record 12 of Set 1 | mangan
# Processing Record 13 of Set 1 | busselton
# Processing Record 14 of Set 1 | barawe
# City not found. Skipping...
# Processing Record 15 of Set 1 | zaysan
# Processing Record 16 of Set 1 | byron bay
# Processing Record 17 of Set 1 | yellowknife
# Processing Record 18 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 19 of Set 1 | miri
# Processing Record 20 of Set 1 | sao joaquim
# Processing Record 21 of Set 1 | narsaq
# Processing Record 22 of Set 1 | san cristobal
# Processing Record 23 of Set 1 | havelock
# Processing Record 24 of Set 1 | roma
# Processing Record 25 of Set 1 | puerto ayora
# Processing Record 26 of Set 1 | fujin
# Processing Record 27 of Set 1 | qaanaaq
# Processing Record 28 of Set 1 | bolungarvik
# City not found. Skipping...
# Processing Record 29 of Set 1 | atuona
# Processing Record 30 of Set 1 | chuy
# Processing Record 31 of Set 1 | punta arenas
# Processing Record 32 of Set 1 | hithadhoo
# Processing Record 33 of Set 1 | rawannawi
# City not found. Skipping...
# Processing Record 34 of Set 1 | hilo
# Processing Record 35 of Set 1 | solnechnyy
# Processing Record 36 of Set 1 | cabo san lucas
# Processing Record 37 of Set 1 | port alfred
# Processing Record 38 of Set 1 | yandyki
# Processing Record 39 of Set 1 | saldanha
# Processing Record 40 of Set 1 | roebourne
# Processing Record 41 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 42 of Set 1 | torbay
# Processing Record 43 of Set 1 | kapaa
# Processing Record 44 of Set 1 | castro
# Processing Record 45 of Set 1 | hambantota
# Processing Record 46 of Set 1 | ponnani
# Processing Record 47 of Set 1 | albany
# Processing Record 48 of Set 1 | yerbogachen
# Processing Record 49 of Set 1 | luwingu
# Processing Record 50 of Set 1 | hamilton
# Processing Record 1 of Set 2 | bethel
# Processing Record 2 of Set 2 | codrington
# Processing Record 3 of Set 2 | los llanos de aridane
# Processing Record 4 of Set 2 | mahebourg
# Processing Record 5 of Set 2 | shakiso
# Processing Record 6 of Set 2 | zachagansk
# City not found. Skipping...
# Processing Record 7 of Set 2 | georgetown
# Processing Record 8 of Set 2 | haibowan
# City not found. Skipping...
# Processing Record 9 of Set 2 | mataura
# Processing Record 10 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 11 of Set 2 | hobart
# Processing Record 12 of Set 2 | norman wells
# Processing Record 13 of Set 2 | yulara
# Processing Record 14 of Set 2 | bredasdorp
# Processing Record 15 of Set 2 | ixtapa
# Processing Record 16 of Set 2 | hermanus
# Processing Record 17 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 18 of Set 2 | cherskiy
# Processing Record 19 of Set 2 | aasiaat
# Processing Record 20 of Set 2 | boende
# Processing Record 21 of Set 2 | cape town
# Processing Record 22 of Set 2 | kamenskoye
# City not found. Skipping...
# Processing Record 23 of Set 2 | blairmore
# Processing Record 24 of Set 2 | lanzhou
# Processing Record 25 of Set 2 | maputo
# Processing Record 26 of Set 2 | smolenka
# Processing Record 27 of Set 2 | lasa
# Processing Record 28 of Set 2 | jamestown
# Processing Record 29 of Set 2 | vaini
# Processing Record 30 of Set 2 | hofn
# Processing Record 31 of Set 2 | ulcinj
# Processing Record 32 of Set 2 | chokurdakh
# Processing Record 33 of Set 2 | karratha
# Processing Record 34 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 35 of Set 2 | beringovskiy
# Processing Record 36 of Set 2 | gimli
# Processing Record 37 of Set 2 | cidreira
# Processing Record 38 of Set 2 | valday
# Processing Record 39 of Set 2 | arraial do cabo
# Processing Record 40 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 41 of Set 2 | kella
# Processing Record 42 of Set 2 | saravan
# Processing Record 43 of Set 2 | manadhoo
# Processing Record 44 of Set 2 | udimskiy
# Processing Record 45 of Set 2 | arman
# Processing Record 46 of Set 2 | itoman
# Processing Record 47 of Set 2 | rikitea
# Processing Record 48 of Set 2 | husavik
# Processing Record 49 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 50 of Set 2 | butaritari
# Processing Record 1 of Set 3 | marrakesh
# Processing Record 2 of Set 3 | ponta do sol
# Processing Record 3 of Set 3 | ha tinh
# Processing Record 4 of Set 3 | iqaluit
# Processing Record 5 of Set 3 | kuusamo
# Processing Record 6 of Set 3 | igarka
# Processing Record 7 of Set 3 | lixourion
# Processing Record 8 of Set 3 | ayan
# Processing Record 9 of Set 3 | horqueta
# Processing Record 10 of Set 3 | pisco
# Processing Record 11 of Set 3 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 12 of Set 3 | cordoba
# Processing Record 13 of Set 3 | nikolskoye
# Processing Record 14 of Set 3 | fredericksburg
# Processing Record 15 of Set 3 | ribeira grande
# Processing Record 16 of Set 3 | verkhnevilyuysk
# Processing Record 17 of Set 3 | lae
# Processing Record 18 of Set 3 | dikson
# Processing Record 19 of Set 3 | jacareacanga
# Processing Record 20 of Set 3 | kavieng
# Processing Record 21 of Set 3 | north bend
# Processing Record 22 of Set 3 | marienburg
# Processing Record 23 of Set 3 | yantarnyy
# Processing Record 24 of Set 3 | barrow
# Processing Record 25 of Set 3 | san patricio
# Processing Record 26 of Set 3 | saint-philippe
# Processing Record 27 of Set 3 | upernavik
# Processing Record 28 of Set 3 | komsomolskiy
# Processing Record 29 of Set 3 | zyryanka
# Processing Record 30 of Set 3 | benguela
# Processing Record 31 of Set 3 | lompoc
# Processing Record 32 of Set 3 | sioux lookout
# Processing Record 33 of Set 3 | srednekolymsk
# Processing Record 34 of Set 3 | la ronge
# Processing Record 35 of Set 3 | teknaf
# Processing Record 36 of Set 3 | ocara
# Processing Record 37 of Set 3 | de-kastri
# Processing Record 38 of Set 3 | alotau
# City not found. Skipping...
# Processing Record 39 of Set 3 | buwenge
# Processing Record 40 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 41 of Set 3 | atkinson
# Processing Record 42 of Set 3 | atlantic beach
# Processing Record 43 of Set 3 | nioro
# Processing Record 44 of Set 3 | banda aceh
# Processing Record 45 of Set 3 | maneromango
# Processing Record 46 of Set 3 | constitucion
# Processing Record 47 of Set 3 | lata
# Processing Record 48 of Set 3 | lebu
# Processing Record 49 of Set 3 | longyearbyen
# Processing Record 50 of Set 3 | portobelo
# Processing Record 1 of Set 4 | hami
# Processing Record 2 of Set 4 | ilulissat
# Processing Record 3 of Set 4 | batemans bay
# Processing Record 4 of Set 4 | dehloran
# Processing Record 5 of Set 4 | puerto baquerizo moreno
# Processing Record 6 of Set 4 | bargal
# City not found. Skipping...
# Processing Record 7 of Set 4 | del rio
# Processing Record 8 of Set 4 | milford
# Processing Record 9 of Set 4 | chapais
# Processing Record 10 of Set 4 | kavaratti
# Processing Record 11 of Set 4 | wanaka
# Processing Record 12 of Set 4 | qixia
# Processing Record 13 of Set 4 | walvis bay
# Processing Record 14 of Set 4 | masjed-e soleyman
# City not found. Skipping...
# Processing Record 15 of Set 4 | dubti
# Processing Record 16 of Set 4 | thompson
# Processing Record 17 of Set 4 | kayerkan
# Processing Record 18 of Set 4 | clyde river
# Processing Record 19 of Set 4 | carnarvon
# Processing Record 20 of Set 4 | skjervoy
# Processing Record 21 of Set 4 | airai
# Processing Record 22 of Set 4 | port lincoln
# Processing Record 23 of Set 4 | vigrestad
# Processing Record 24 of Set 4 | souillac
# Processing Record 25 of Set 4 | camana
# Processing Record 26 of Set 4 | rawson
# Processing Record 27 of Set 4 | warqla
# City not found. Skipping...
# Processing Record 28 of Set 4 | nuuk
# Processing Record 29 of Set 4 | carutapera
# Processing Record 30 of Set 4 | east london
# Processing Record 31 of Set 4 | ciudad bolivar
# Processing Record 32 of Set 4 | fortuna
# Processing Record 33 of Set 4 | paamiut
# Processing Record 34 of Set 4 | vila
# Processing Record 35 of Set 4 | asau
# Processing Record 36 of Set 4 | ambilobe
# Processing Record 37 of Set 4 | ngukurr
# City not found. Skipping...
# Processing Record 38 of Set 4 | skalistyy
# City not found. Skipping...
# Processing Record 39 of Set 4 | cartagena del chaira
# Processing Record 40 of Set 4 | new norfolk
# Processing Record 41 of Set 4 | faanui
# Processing Record 42 of Set 4 | meulaboh
# Processing Record 43 of Set 4 | rafraf
# Processing Record 44 of Set 4 | isangel
# Processing Record 45 of Set 4 | abha
# Processing Record 46 of Set 4 | hasaki
# Processing Record 47 of Set 4 | santiago del estero
# Processing Record 48 of Set 4 | makakilo city
# Processing Record 49 of Set 4 | galiwinku
# City not found. Skipping...
# Processing Record 50 of Set 4 | khatanga
# Processing Record 1 of Set 5 | innisfail
# Processing Record 2 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 3 of Set 5 | basco
# Processing Record 4 of Set 5 | andra
# Processing Record 5 of Set 5 | dawlatabad
# Processing Record 6 of Set 5 | nanortalik
# Processing Record 7 of Set 5 | luderitz
# Processing Record 8 of Set 5 | berlevag
# Processing Record 9 of Set 5 | sovetskiy
# Processing Record 10 of Set 5 | shu
# Processing Record 11 of Set 5 | mayo
# Processing Record 12 of Set 5 | bluff
# Processing Record 13 of Set 5 | vao
# Processing Record 14 of Set 5 | beyneu
# Processing Record 15 of Set 5 | scottsburgh
# City not found. Skipping...
# Processing Record 16 of Set 5 | matamoros
# Processing Record 17 of Set 5 | shelburne
# Processing Record 18 of Set 5 | adrar
# Processing Record 19 of Set 5 | kalmunai
# Processing Record 20 of Set 5 | santa isabel do rio negro
# Processing Record 21 of Set 5 | the valley
# Processing Record 22 of Set 5 | pevek
# Processing Record 23 of Set 5 | havre-saint-pierre
# Processing Record 24 of Set 5 | kijang
# Processing Record 25 of Set 5 | saskylakh
# Processing Record 26 of Set 5 | charters towers
# Processing Record 27 of Set 5 | rosita
# Processing Record 28 of Set 5 | college
# Processing Record 29 of Set 5 | vytegra
# Processing Record 30 of Set 5 | tucurui
# Processing Record 31 of Set 5 | kaerepere
# Processing Record 32 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 33 of Set 5 | nhulunbuy
# Processing Record 34 of Set 5 | malakal
# Processing Record 35 of Set 5 | amahai
# Processing Record 36 of Set 5 | saint-augustin
# Processing Record 37 of Set 5 | saint george
# Processing Record 38 of Set 5 | tambura
# Processing Record 39 of Set 5 | ambon
# Processing Record 40 of Set 5 | klaksvik
# Processing Record 41 of Set 5 | mayumba
# Processing Record 42 of Set 5 | kazachinskoye
# Processing Record 43 of Set 5 | sao filipe
# Processing Record 44 of Set 5 | provideniya
# Processing Record 45 of Set 5 | alofi
# Processing Record 46 of Set 5 | nizhnyaya tura
# Processing Record 47 of Set 5 | tasiilaq
# Processing Record 48 of Set 5 | mangaluru
# Processing Record 49 of Set 5 | sao joao da barra
# Processing Record 50 of Set 5 | narbonne
# Processing Record 1 of Set 6 | tautira
# Processing Record 2 of Set 6 | soyo
# Processing Record 3 of Set 6 | leningradskiy
# Processing Record 4 of Set 6 | klembivka
# Processing Record 5 of Set 6 | cayenne
# Processing Record 6 of Set 6 | qafsah
# City not found. Skipping...
# Processing Record 7 of Set 6 | saint-pierre
# Processing Record 8 of Set 6 | severnyy
# Processing Record 9 of Set 6 | arlit
# Processing Record 10 of Set 6 | bengkulu
# Processing Record 11 of Set 6 | domodossola
# Processing Record 12 of Set 6 | jaroslaw
# Processing Record 13 of Set 6 | utete
# Processing Record 14 of Set 6 | hobyo
# Processing Record 15 of Set 6 | kamenka
# Processing Record 16 of Set 6 | skibbereen
# Processing Record 17 of Set 6 | neryungri
# Processing Record 18 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 19 of Set 6 | sydney
# Processing Record 20 of Set 6 | madarounfa
# Processing Record 21 of Set 6 | bilma
# Processing Record 22 of Set 6 | esperance
# Processing Record 23 of Set 6 | jijiga
# Processing Record 24 of Set 6 | vila franca do campo
# Processing Record 25 of Set 6 | ponta delgada
# Processing Record 26 of Set 6 | praya
# Processing Record 27 of Set 6 | buraydah
# Processing Record 28 of Set 6 | port hardy
# Processing Record 29 of Set 6 | romny
# Processing Record 30 of Set 6 | tombouctou
# Processing Record 31 of Set 6 | sisimiut
# Processing Record 32 of Set 6 | caravelas
# Processing Record 33 of Set 6 | port elizabeth
# Processing Record 34 of Set 6 | riyadh
# Processing Record 35 of Set 6 | zhigansk
# Processing Record 36 of Set 6 | saint-joseph
# Processing Record 37 of Set 6 | ipaussu
# Processing Record 38 of Set 6 | karaton
# Processing Record 39 of Set 6 | oranjemund
# Processing Record 40 of Set 6 | severo-kurilsk
# Processing Record 41 of Set 6 | sturgeon falls
# Processing Record 42 of Set 6 | fallon
# Processing Record 43 of Set 6 | dubbo
# Processing Record 44 of Set 6 | mar del plata
# Processing Record 45 of Set 6 | derbent
# Processing Record 46 of Set 6 | rorvik
# Processing Record 47 of Set 6 | grand gaube
# Processing Record 48 of Set 6 | hokitika
# Processing Record 49 of Set 6 | harper
# Processing Record 50 of Set 6 | montataire
# Processing Record 1 of Set 7 | sorong
# Processing Record 2 of Set 7 | makung
# City not found. Skipping...
# Processing Record 3 of Set 7 | shawinigan
# Processing Record 4 of Set 7 | bulgan
# Processing Record 5 of Set 7 | laguna
# Processing Record 6 of Set 7 | clermont
# Processing Record 7 of Set 7 | tahe
# Processing Record 8 of Set 7 | kodiak
# Processing Record 9 of Set 7 | encheng
# Processing Record 10 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 11 of Set 7 | nurota
# Processing Record 12 of Set 7 | paradwip
# City not found. Skipping...
# Processing Record 13 of Set 7 | coruripe
# Processing Record 14 of Set 7 | eyl
# Processing Record 15 of Set 7 | lavrentiya
# Processing Record 16 of Set 7 | faya
# Processing Record 17 of Set 7 | natal
# Processing Record 18 of Set 7 | mogadishu
# Processing Record 19 of Set 7 | mugur-aksy
# Processing Record 20 of Set 7 | noumea
# Processing Record 21 of Set 7 | marathopolis
# City not found. Skipping...
# Processing Record 22 of Set 7 | marovoay
# Processing Record 23 of Set 7 | eydhafushi
# Processing Record 24 of Set 7 | kupang
# Processing Record 25 of Set 7 | maragogi
# Processing Record 26 of Set 7 | talnakh
# Processing Record 27 of Set 7 | mutoko
# Processing Record 28 of Set 7 | nizip
# Processing Record 29 of Set 7 | russell
# Processing Record 30 of Set 7 | sitka
# Processing Record 31 of Set 7 | bonavista
# Processing Record 32 of Set 7 | ilo
# Processing Record 33 of Set 7 | namibe
# Processing Record 34 of Set 7 | auki
# Processing Record 35 of Set 7 | lorengau
# Processing Record 36 of Set 7 | lazaro cardenas
# Processing Record 37 of Set 7 | necochea
# Processing Record 38 of Set 7 | nelson bay
# Processing Record 39 of Set 7 | shahr-e kord
# Processing Record 40 of Set 7 | mehamn
# Processing Record 41 of Set 7 | bodden town
# Processing Record 42 of Set 7 | bambous virieux
# Processing Record 43 of Set 7 | tambul
# City not found. Skipping...
# Processing Record 44 of Set 7 | aykhal
# Processing Record 45 of Set 7 | katsuura
# Processing Record 46 of Set 7 | winona
# Processing Record 47 of Set 7 | dingle
# Processing Record 48 of Set 7 | monteagudo
# Processing Record 49 of Set 7 | mao
# Processing Record 50 of Set 7 | wad rawah
# Processing Record 1 of Set 8 | coihaique
# Processing Record 2 of Set 8 | gamba
# Processing Record 3 of Set 8 | kidal
# Processing Record 4 of Set 8 | phayakkhaphum phisai
# Processing Record 5 of Set 8 | saint anthony
# Processing Record 6 of Set 8 | victoria
# Processing Record 7 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 8 of Set 8 | valparaiso
# Processing Record 9 of Set 8 | nampula
# Processing Record 10 of Set 8 | aswan
# Processing Record 11 of Set 8 | kutum
# Processing Record 12 of Set 8 | bonoua
# Processing Record 13 of Set 8 | halalo
# City not found. Skipping...
# Processing Record 14 of Set 8 | mareeba
# Processing Record 15 of Set 8 | pyshchug
# Processing Record 16 of Set 8 | salalah
# Processing Record 17 of Set 8 | kohima
# Processing Record 18 of Set 8 | brae
# Processing Record 19 of Set 8 | tilichiki
# Processing Record 20 of Set 8 | coahuayana
# Processing Record 21 of Set 8 | hushitai
# Processing Record 22 of Set 8 | sibolga
# Processing Record 23 of Set 8 | richards bay
# Processing Record 24 of Set 8 | codajas
# Processing Record 25 of Set 8 | aklavik
# Processing Record 26 of Set 8 | dandong
# Processing Record 27 of Set 8 | pinawa
# Processing Record 28 of Set 8 | maningrida
# Processing Record 29 of Set 8 | olafsvik
# Processing Record 30 of Set 8 | geraldton
# Processing Record 31 of Set 8 | gebze
# Processing Record 32 of Set 8 | gizo
# Processing Record 33 of Set 8 | general higinio morinigo
# Processing Record 34 of Set 8 | kuminskiy
# Processing Record 35 of Set 8 | hailar
# Processing Record 36 of Set 8 | vardo
# Processing Record 37 of Set 8 | yaguajay
# Processing Record 38 of Set 8 | galle
# Processing Record 39 of Set 8 | ostrovnoy
# Processing Record 40 of Set 8 | kollumerland
# City not found. Skipping...
# Processing Record 41 of Set 8 | pafos
# Processing Record 42 of Set 8 | esterhazy
# Processing Record 43 of Set 8 | baruun-urt
# Processing Record 44 of Set 8 | devli
# Processing Record 45 of Set 8 | pacifica
# Processing Record 46 of Set 8 | terrace
# Processing Record 47 of Set 8 | ulaangom
# Processing Record 48 of Set 8 | panjwin
# City not found. Skipping...
# Processing Record 49 of Set 8 | quechultenango
# Processing Record 50 of Set 8 | sao lourenco do sul
# Processing Record 1 of Set 9 | yacuiba
# Processing Record 2 of Set 9 | suntar
# Processing Record 3 of Set 9 | lokoja
# Processing Record 4 of Set 9 | abyek
# Processing Record 5 of Set 9 | buariki
# City not found. Skipping...
# Processing Record 6 of Set 9 | poya
# Processing Record 7 of Set 9 | volchikha
# Processing Record 8 of Set 9 | beeville
# Processing Record 9 of Set 9 | shieli
# Processing Record 10 of Set 9 | diamantino
# Processing Record 11 of Set 9 | batsfjord
# Processing Record 12 of Set 9 | northam
# Processing Record 13 of Set 9 | kanniyakumari
# Processing Record 14 of Set 9 | rawatsar
# Processing Record 15 of Set 9 | ruatoria
# City not found. Skipping...
# Processing Record 16 of Set 9 | padang
# Processing Record 17 of Set 9 | ternate
# Processing Record 18 of Set 9 | kokopo
# Processing Record 19 of Set 9 | carbonear
# Processing Record 20 of Set 9 | toguchin
# Processing Record 21 of Set 9 | dalby
# Processing Record 22 of Set 9 | beloha
# Processing Record 23 of Set 9 | grand centre
# City not found. Skipping...
# Processing Record 24 of Set 9 | progreso
# Processing Record 25 of Set 9 | pierre
# Processing Record 26 of Set 9 | rossland
# Processing Record 27 of Set 9 | dwarka
# Processing Record 28 of Set 9 | port-de-paix
# City not found. Skipping...
# Processing Record 29 of Set 9 | high level
# Processing Record 30 of Set 9 | coulommiers
# Processing Record 31 of Set 9 | vreed en hoop
# City not found. Skipping...
# Processing Record 32 of Set 9 | okha
# Processing Record 33 of Set 9 | zhangjiakou
# Processing Record 34 of Set 9 | kita
# Processing Record 35 of Set 9 | borgarnes
# Processing Record 36 of Set 9 | pemba
# Processing Record 37 of Set 9 | pangnirtung
# Processing Record 38 of Set 9 | mian channun
# Processing Record 39 of Set 9 | balakirevo
# Processing Record 40 of Set 9 | yichang
# Processing Record 41 of Set 9 | nishihara
# Processing Record 42 of Set 9 | fort nelson
# Processing Record 43 of Set 9 | thiruvananthapuram
# Processing Record 44 of Set 9 | riberalta
# Processing Record 45 of Set 9 | grindavik
# Processing Record 46 of Set 9 | leticia
# Processing Record 47 of Set 9 | calimanesti
# Processing Record 48 of Set 9 | olinda
# Processing Record 49 of Set 9 | ulsteinvik
# Processing Record 50 of Set 9 | zapolyarnyy
# Processing Record 1 of Set 10 | lima
# Processing Record 2 of Set 10 | ust-uda
# Processing Record 3 of Set 10 | barcelos
# Processing Record 4 of Set 10 | werda
# Processing Record 5 of Set 10 | pangkalanbuun
# Processing Record 6 of Set 10 | raahe
# Processing Record 7 of Set 10 | bayangol
# Processing Record 8 of Set 10 | marawi
# Processing Record 9 of Set 10 | parkes
# Processing Record 10 of Set 10 | pakhtakoron
# Processing Record 11 of Set 10 | touros
# Processing Record 12 of Set 10 | suhbaatar
# Processing Record 13 of Set 10 | chekmagush
# Processing Record 14 of Set 10 | wajima
# Processing Record 15 of Set 10 | rafai
# Processing Record 16 of Set 10 | hastings
# Processing Record 17 of Set 10 | korla
# Processing Record 18 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 19 of Set 10 | praia
# Processing Record 20 of Set 10 | san andres
# Processing Record 21 of Set 10 | tshikapa
# Processing Record 22 of Set 10 | dovolnoye
# Processing Record 23 of Set 10 | bilibino
# Processing Record 24 of Set 10 | san policarpo
# Processing Record 25 of Set 10 | moerai
# Processing Record 26 of Set 10 | sanchursk
# Processing Record 27 of Set 10 | leshukonskoye
# Processing Record 28 of Set 10 | azimur
# City not found. Skipping...
# Processing Record 29 of Set 10 | tuatapere
# Processing Record 30 of Set 10 | kyren
# Processing Record 31 of Set 10 | ushtobe
# Processing Record 32 of Set 10 | strai
# Processing Record 33 of Set 10 | victor harbor
# Processing Record 34 of Set 10 | garmsar
# Processing Record 35 of Set 10 | karasburg
# Processing Record 36 of Set 10 | turayf
# Processing Record 37 of Set 10 | kichera
# Processing Record 38 of Set 10 | yongan
# Processing Record 39 of Set 10 | flinders
# Processing Record 40 of Set 10 | chumikan
# Processing Record 41 of Set 10 | matay
# Processing Record 42 of Set 10 | yankton
# Processing Record 43 of Set 10 | butag
# Processing Record 44 of Set 10 | madang
# Processing Record 45 of Set 10 | ibra
# Processing Record 46 of Set 10 | burica
# City not found. Skipping...
# Processing Record 47 of Set 10 | yatou
# Processing Record 48 of Set 10 | sergeyevka
# Processing Record 49 of Set 10 | lensk
# Processing Record 50 of Set 10 | khakhea
# Processing Record 1 of Set 11 | pimenta bueno
# Processing Record 2 of Set 11 | mount gambier
# Processing Record 3 of Set 11 | tamuin
# Processing Record 4 of Set 11 | wulanhaote
# City not found. Skipping...
# Processing Record 5 of Set 11 | pimentel
# Processing Record 6 of Set 11 | sankeshwar
# Processing Record 7 of Set 11 | kununurra
# Processing Record 8 of Set 11 | dong hoi
# Processing Record 9 of Set 11 | toliary
# City not found. Skipping...
# Processing Record 10 of Set 11 | quelimane
# Processing Record 11 of Set 11 | kawalu
# Processing Record 12 of Set 11 | qasigiannguit
# Processing Record 13 of Set 11 | qeshm
# Processing Record 14 of Set 11 | karauzyak
# City not found. Skipping...
# Processing Record 15 of Set 11 | benito juarez
# Processing Record 16 of Set 11 | imbituba
# Processing Record 17 of Set 11 | gojo
# Processing Record 18 of Set 11 | payo
# Processing Record 19 of Set 11 | nantucket
# Processing Record 20 of Set 11 | pakxan
# Processing Record 21 of Set 11 | otjiwarongo
# Processing Record 22 of Set 11 | santa lucia
# Processing Record 23 of Set 11 | nome
# Processing Record 24 of Set 11 | comodoro rivadavia
# Processing Record 25 of Set 11 | kenai
# Processing Record 26 of Set 11 | mount isa
# Processing Record 27 of Set 11 | lubumbashi
# Processing Record 28 of Set 11 | shache
# Processing Record 29 of Set 11 | sumbawa
# City not found. Skipping...
# Processing Record 30 of Set 11 | nalut
# Processing Record 31 of Set 11 | wisconsin rapids
# Processing Record 32 of Set 11 | borogontsy
# Processing Record 33 of Set 11 | vila velha
# Processing Record 34 of Set 11 | marsh harbour
# Processing Record 35 of Set 11 | samana
# Processing Record 36 of Set 11 | la palma
# Processing Record 37 of Set 11 | al
# City not found. Skipping...
# Processing Record 38 of Set 11 | tatishchevo
# Processing Record 39 of Set 11 | kaseda
# Processing Record 40 of Set 11 | altus
# Processing Record 41 of Set 11 | tondano
# Processing Record 42 of Set 11 | borama
# City not found. Skipping...
# Processing Record 43 of Set 11 | vlore
# Processing Record 44 of Set 11 | lagoa
# Processing Record 45 of Set 11 | khandyga
# Processing Record 46 of Set 11 | wadena
# Processing Record 47 of Set 11 | san antonio
# Processing Record 48 of Set 11 | kabala
# Processing Record 49 of Set 11 | paramirim
# Processing Record 50 of Set 11 | antofagasta
# Processing Record 1 of Set 12 | kloulklubed
# Processing Record 2 of Set 12 | lakhtar
# Processing Record 3 of Set 12 | stellenbosch
# Processing Record 4 of Set 12 | deder
# Processing Record 5 of Set 12 | huarmey
# Processing Record 6 of Set 12 | belaya gora
# Processing Record 7 of Set 12 | kudahuvadhoo
# Processing Record 8 of Set 12 | rio grande
# Processing Record 9 of Set 12 | sangar
# Processing Record 10 of Set 12 | cervo
# Processing Record 11 of Set 12 | rindal
# Processing Record 12 of Set 12 | sentyabrskiy
# City not found. Skipping...
# Processing Record 13 of Set 12 | chkalovsk
# Processing Record 14 of Set 12 | pangody
# Processing Record 15 of Set 12 | le pradet
# Processing Record 16 of Set 12 | chontalpa
# Processing Record 17 of Set 12 | luanda
# Processing Record 18 of Set 12 | the pas
# Processing Record 19 of Set 12 | kruisfontein
# Processing Record 20 of Set 12 | johnson city
# Processing Record 21 of Set 12 | mantua
# Processing Record 22 of Set 12 | loubomo
# Processing Record 23 of Set 12 | half moon bay
# Processing Record 24 of Set 12 | busayra
# Processing Record 25 of Set 12 | istok
# Processing Record 26 of Set 12 | namtsy
# Processing Record 27 of Set 12 | sigli
# Processing Record 28 of Set 12 | khovu-aksy
# Processing Record 29 of Set 12 | san vicente
# Processing Record 30 of Set 12 | disna
# Processing Record 31 of Set 12 | boa vista
# Processing Record 32 of Set 12 | banswara
# Processing Record 33 of Set 12 | ferrol
# Processing Record 34 of Set 12 | hereford
# Processing Record 35 of Set 12 | nemuro
# Processing Record 36 of Set 12 | prince rupert
# Processing Record 37 of Set 12 | butler
# Processing Record 38 of Set 12 | bara
# Processing Record 39 of Set 12 | kitimat
# Processing Record 40 of Set 12 | deputatskiy
# Processing Record 41 of Set 12 | cockburn town
# Processing Record 42 of Set 12 | awjilah
# Processing Record 43 of Set 12 | kesennuma
# City not found. Skipping...
# Processing Record 44 of Set 12 | saint-georges
# Processing Record 45 of Set 12 | yumen
# Processing Record 46 of Set 12 | san jeronimo
# Processing Record 47 of Set 12 | viedma
# Processing Record 48 of Set 12 | tiznit
# Processing Record 49 of Set 12 | flin flon
# Processing Record 50 of Set 12 | carnot
# Processing Record 1 of Set 13 | sharjah
# Processing Record 2 of Set 13 | xam nua
# Processing Record 3 of Set 13 | portland
# Processing Record 4 of Set 13 | kuching
# Processing Record 5 of Set 13 | kurumkan
# Processing Record 6 of Set 13 | tyukhtet
# Processing Record 7 of Set 13 | bahia blanca
# Processing Record 8 of Set 13 | fairbanks
# Processing Record 9 of Set 13 | koroni
# Processing Record 10 of Set 13 | zverinogolovskoye
# Processing Record 11 of Set 13 | povenets
# Processing Record 12 of Set 13 | la cruz
# Processing Record 13 of Set 13 | fare
# Processing Record 14 of Set 13 | mizdah
# Processing Record 15 of Set 13 | shelton
# Processing Record 16 of Set 13 | raja sansi
# Processing Record 17 of Set 13 | chengde
# Processing Record 18 of Set 13 | ancud
# Processing Record 19 of Set 13 | vanavara
# Processing Record 20 of Set 13 | ojiya
# Processing Record 21 of Set 13 | mmathubudukwane
# Processing Record 22 of Set 13 | greymouth
# Processing Record 23 of Set 13 | zhangye
# Processing Record 24 of Set 13 | broken hill
# Processing Record 25 of Set 13 | helong
# Processing Record 26 of Set 13 | kashary
# Processing Record 27 of Set 13 | labuhan
# Processing Record 28 of Set 13 | maceio
# Processing Record 29 of Set 13 | dolbeau
# City not found. Skipping...
# Processing Record 30 of Set 13 | kaoma
# Processing Record 31 of Set 13 | te anau
# Processing Record 32 of Set 13 | gandiaye
# Processing Record 33 of Set 13 | pacific grove
# Processing Record 34 of Set 13 | iwanai
# Processing Record 35 of Set 13 | nara
# Processing Record 36 of Set 13 | luangwa
# Processing Record 37 of Set 13 | sayanskiy
# City not found. Skipping...
# Processing Record 38 of Set 13 | taburi
# City not found. Skipping...
# Processing Record 39 of Set 13 | bay roberts
# Processing Record 40 of Set 13 | lhuntshi
# City not found. Skipping...
# Processing Record 41 of Set 13 | huicheng
# Processing Record 42 of Set 13 | vicuna
# Processing Record 43 of Set 13 | inhambane
# Processing Record 44 of Set 13 | barcelona
# Processing Record 45 of Set 13 | jinchengjiang
# City not found. Skipping...
# Processing Record 46 of Set 13 | bathsheba
# Processing Record 47 of Set 13 | ostersund
# Processing Record 48 of Set 13 | karaul
# City not found. Skipping...
# Processing Record 49 of Set 13 | mergui
# City not found. Skipping...
# Processing Record 50 of Set 13 | tacna
# Processing Record 1 of Set 14 | taksimo
# Processing Record 2 of Set 14 | hammerfest
# Processing Record 3 of Set 14 | belmonte
# Processing Record 4 of Set 14 | garowe
# Processing Record 5 of Set 14 | okahandja
# Processing Record 6 of Set 14 | lamu
# Processing Record 7 of Set 14 | lodhikheda
# Processing Record 8 of Set 14 | tehachapi
# Processing Record 9 of Set 14 | saint-francois
# Processing Record 10 of Set 14 | carikar
# City not found. Skipping...
# Processing Record 11 of Set 14 | bireun
# Processing Record 12 of Set 14 | axim
# Processing Record 13 of Set 14 | olocuilta
# Processing Record 14 of Set 14 | yarmouth
# Processing Record 15 of Set 14 | abbotsford
# Processing Record 16 of Set 14 | kenda
# Processing Record 17 of Set 14 | xingyi
# Processing Record 18 of Set 14 | camapua
# Processing Record 19 of Set 14 | iracoubo
# Processing Record 20 of Set 14 | jieshou
# Processing Record 21 of Set 14 | gat
# Processing Record 22 of Set 14 | hailey
# Processing Record 23 of Set 14 | general pico
# Processing Record 24 of Set 14 | decatur
# Processing Record 25 of Set 14 | asayita
# City not found. Skipping...
# Processing Record 26 of Set 14 | samarai
# Processing Record 27 of Set 14 | phan thiet
# Processing Record 28 of Set 14 | enshi
# Processing Record 29 of Set 14 | rungata
# City not found. Skipping...
# Processing Record 30 of Set 14 | deep river
# Processing Record 31 of Set 14 | mordovo
# Processing Record 32 of Set 14 | abonnema
# Processing Record 33 of Set 14 | antipino
# Processing Record 34 of Set 14 | longyan
# Processing Record 35 of Set 14 | kaeo
# Processing Record 36 of Set 14 | svarstad
# Processing Record 37 of Set 14 | yining
# Processing Record 38 of Set 14 | synya
# Processing Record 39 of Set 14 | den helder
# Processing Record 40 of Set 14 | awassa
# Processing Record 41 of Set 14 | waipawa
# Processing Record 42 of Set 14 | bestobe
# Processing Record 43 of Set 14 | port hedland
# Processing Record 44 of Set 14 | alpena
# Processing Record 45 of Set 14 | muravlenko
# Processing Record 46 of Set 14 | casa grande
# Processing Record 47 of Set 14 | broome
# Processing Record 48 of Set 14 | qianan
# Processing Record 49 of Set 14 | noyabrsk
# Processing Record 50 of Set 14 | nopaltepec
# Processing Record 1 of Set 15 | ryotsu
# Processing Record 2 of Set 15 | standerton
# Processing Record 3 of Set 15 | lingao
# Processing Record 4 of Set 15 | iroquois falls
# Processing Record 5 of Set 15 | buala
# Processing Record 6 of Set 15 | steenbergen
# Processing Record 7 of Set 15 | nabire
# Processing Record 8 of Set 15 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 9 of Set 15 | bonthe
# Processing Record 10 of Set 15 | pastavy
# Processing Record 11 of Set 15 | graham
# Processing Record 12 of Set 15 | washington
# Processing Record 13 of Set 15 | nouadhibou
# Processing Record 14 of Set 15 | maniitsoq
# Processing Record 15 of Set 15 | hervey bay
# Processing Record 16 of Set 15 | les cayes
# Processing Record 17 of Set 15 | san pedro
# Processing Record 18 of Set 15 | havoysund
# Processing Record 19 of Set 15 | atasu
# Processing Record 20 of Set 15 | tabiauea
# City not found. Skipping...
# Processing Record 21 of Set 15 | miyako
# Processing Record 22 of Set 15 | southbridge
# Processing Record 23 of Set 15 | porto nacional
# Processing Record 24 of Set 15 | ahipara
# Processing Record 25 of Set 15 | ksenyevka
# City not found. Skipping...
# Processing Record 26 of Set 15 | asyut
# Processing Record 27 of Set 15 | vaitupu
# City not found. Skipping...
# Processing Record 28 of Set 15 | biggar
# Processing Record 29 of Set 15 | abu jubayhah
# City not found. Skipping...
# Processing Record 30 of Set 15 | chokwe
# Processing Record 31 of Set 15 | quepos
# Processing Record 32 of Set 15 | sola
# Processing Record 33 of Set 15 | porto walter
# Processing Record 34 of Set 15 | puerto escondido
# Processing Record 35 of Set 15 | gladstone
# Processing Record 36 of Set 15 | qazanbulaq
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(cities)
# Out:
# 736

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#                  City Country      Lat       Lng  Max Temp  Humidity  \
# 0             Ushuaia      AR -54.8000  -68.3000     30.87        85
# 1          Port Blair      IN  11.6667   92.7500     84.36        77
# 2         Tuktoyaktuk      CA  69.4541 -133.0374     60.80        82
# 3             Radford      US  37.1318  -80.5764     72.52        81
# 4      Guerrero Negro      MX  27.9769 -114.0611     72.36        80
# ..                ...     ...      ...       ...       ...       ...
# 663              Sola      VU -13.8833  167.5500     77.97        69
# 664      Porto Walter      BR  -8.2686  -72.7439     63.55        67
# 665  Puerto Escondido      MX  15.8500  -97.0667     81.43        69
# 666         Gladstone      AU -23.8500  151.2500     75.78        56
# 667        Qazanbulaq      AZ  40.6192   46.6519     76.10        48
#
#      Cloudiness  Wind Speed Current Description
# 0            57        5.61       broken clouds
# 1            61       17.65       broken clouds
# 2            75        8.05       broken clouds
# 3             1        3.44           clear sky
# 4            25        9.89    scattered clouds
# ..          ...         ...                 ...
# 663          84       12.39       broken clouds
# 664           3        0.13           clear sky
# 665          40        5.75    scattered clouds
# 666          22       10.36          light rain
# 667           4        0.74           clear sky
#
# [668 rows x 9 columns]
