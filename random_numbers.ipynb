# %% [markdown]
# # 6.1.4 Generate Random Latitudes and Longitudes

# %% [markdown]
# ## The Random Module

# %%
# Import the random module.
import random

# %%
# Type random., and after the period, press the Tab key for a list of available random module functions
#random.

# %% [markdown]
# ## The randint() Function

# %%
random.randint(-90,90)
# Out:
# -15

# %% [markdown]
# ## The random() Function

# %%
# Get a single floating-point decimal number between 0 and 1.0
random.random()
# Out:
# 0.5980332804548633

# %%
# Combine the two to generate a floating-point decimal (latitude) between -90 and and 90 
random_number = random.randint(-90,89) + random.random()
random_number
# Out:
# 26.27891424503307

# %%
# Write an algorithm that will generate ten latitudes between –90 and 89
x = 1
latitudes = []
while x < 11:
    random_lat = random.randint(-90, 89) + random.random()
    latitudes.append(random_lat)
    x += 1
    
latitudes
# Out:
# [45.75774210535757,
#  35.285519602780134,
#  17.343964119753327,
#  -33.98353808238004,
#  23.14829416528819,
#  -1.1847497817251198,
#  87.66416797105481,
#  -18.347823862244216,
#  -71.00976348913242,
#  -28.732219838688152]

# %% [markdown]
# ## The randrange() Function

# %%
# The output is a number between -90 and 90, where the step is the difference between each number in the sequence
random.randrange(-90, 90, step=1)
# Out:
# 72

# %%
random.randrange(-90, 90, step=3)
# Out:
# -3

# %% [markdown]
# ## The uniform() Function

# %%
random.uniform(-90, 90)
# Out:
# 57.033652988718586

# %% [markdown]
# ## The NumPy and random Modules

# %%
# Import the NumPy module.
import numpy as np

# %%
# When using the NumPy module with the random.uniform() function, the parenthetical parameters contain a lower boundary (low value) and an upper boundary (high value) that are floating-point decimal numbers
# Can also be written as np.random.uniform(low=-90, high=90)
np.random.uniform(-90.000, 90.000)
# Out:
# 33.98344656452572

# %%
# To generate more than one floating-point decimal number between –90 and 90, we can add the size parameter when we use the NumPy module and set that equal to any whole number
np.random.uniform(-90.000, 90.000, size=50)
# Out:
# array([ 11.13817957,  24.77874457,  89.64984365,  68.53142985,
#         66.14209554, -37.8447572 ,  44.63989066,  88.12840054,
#         87.30319871,  74.8164808 , -65.31522227, -13.82934912,
#        -62.94568219,  11.87642755,  84.04008344,  33.76565287,
#        -86.47673046,  15.73378105,  25.57556429, -43.32929983,
#          5.02141657, -39.12259944,  16.77993637,  45.41758517,
#         61.77071011,  86.08688624, -60.3307047 ,  74.49801253,
#          1.49196911, -89.32896406, -79.46364743,  64.9566945 ,
#        -72.11577505,  53.62570772,  88.5592879 ,  88.38041363,
#         -2.85268203, -81.93789838, -76.54977188,   7.77965318,
#         32.73023914,  37.81067199, -42.37333663, -64.40904123,
#         77.85525947,   2.23608808,  83.6572128 ,  -3.99718579,
#         82.88709843,  28.71603268])

# %%
# Import timeit.
import timeit

# %%
# Use in front of previous code to time how long the piece of code takes to run
# %timeit np.random.uniform(-90.000, 90.000, size=1500)
# Out:
# 17.4 µs ± 58.4 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
# Run the while loop as a function. 
def latitudes(size):
    latitudes = []
    x = 0
    while x < (size):
        random_lat = random.randint(-90, 90) + random.random()
        latitudes.append(random_lat)
        x += 1
    return latitudes

# Call the function with 1500.
# %timeit latitudes(1500)
# Out:
# 2.51 ms ± 195 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# SKILL DRILL
# Refactor the code for the while loop with the %timeit magic command and write a for loop that will generate 1,500 latitudes
def generateLatitudes(size):
    latitudes = []
    
    for x in range(0, size):
        random_lat = random.randint(-90, 90) + random.random()
        latitudes.append(random_lat)
    return latitudes

# Call the function with 1500.
generateLatitudes(1500)
# Out:
# [23.041084265363597,
#  30.760363677143708,
#  -48.89618010003752,
#  -35.23626695548707,
#  44.247856993279136,
#  87.28356934289937,
#  -81.29717712909071,
#  31.116439473730406,
#  72.61538300168478,
#  -45.817949638924475,
#  3.049371228864003,
#  -64.6055714918409,
#  -82.6500729330605,
#  -84.46688940327164,
#  -50.33471338143915,
#  -33.394340191318015,
#  81.41189745108227,
#  76.27345566686967,
#  50.99398562697333,
#  69.06265803121767,
#  -30.74468916833861,
#  78.442627755377,
#  37.03623491250451,
#  30.708791008551614,
#  -37.285995812454814,
#  -72.17124360477789,
#  83.40002984834514,
#  -0.676544707158,
#  81.45062703191938,
#  -22.2601536551046,
#  -82.24949822992639,
#  65.65515699758576,
#  68.97887983900986,
#  -81.84274167314588,
#  60.0619134048931,
#  13.09824456063627,
#  -82.57524162464881,
#  57.07362109172237,
#  -43.57255261853761,
#  3.872904533512191,
#  -74.55609541987974,
#  34.948355451876196,
#  -12.34513384922559,
#  6.195203189686467,
# ...

# %% [markdown]
# # 6.4.1 Use Linear Regression to Find the Relationship Between Variables

# %%
# Import linear regression from the SciPy stats module.
from scipy.stats import linregress

# %%
# Create an equal number of latitudes and temperatures. Lats are positive = all in northern hemisphere
lats = [42.5, 43.9, 8.1, 36.8, 79.9, 69.1, 25.7, 15.3, 12.7, 64.5]
temps = [80.5, 75.3, 90.9, 90.0, 40.4, 62.3, 85.4, 79.6, 72.5, 72.0]

# %%
# Perform linear regression.
(slope, intercept, r_value, p_value, std_err) = linregress(lats, temps)

# Get the equation of the line.
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(line_eq)
print(f"The p-value is: {p_value:.3f}")
# Out:
# y = -0.45x + 92.94
# The p-value is: 0.011

# %%
# Calculate the regression line "y values" from the slope and intercept.
regress_values = [(lat * slope + intercept) for lat in lats]

# %%
# Import Matplotlib.
import matplotlib.pyplot as plt

# Create a scatter plot of the x and y values.
plt.scatter(lats,temps)

# Plot the regression line with the x-values and the y coordinates based on the intercept and slope.
plt.plot(lats,regress_values,"r")

# Annotate the text for the line equation and add its coordinates.
plt.annotate(line_eq, (10,40), fontsize=15, color="red")
plt.xlabel('Latitude')
plt.ylabel('Temp')
plt.show()
